# %% [markdown]
# # Data Storytelling and Preliminary Analysis

# %% [markdown]
# ## Questions I Asked:

# %% [markdown]
# __1. How has the urban population (as percentage of total) changed over the timespan in the dataset?__
#
#     In 1972, the average urban population (as percentage of total) was 43.16%. In 2002, it was 55.02%. When broken down by region, North America had the smallest change in urban population (as percentage of total), while Sub-Sarahan Africa had the largest. When analyzing countries grouped by income levels, we see a negative correlation with the already densely-populated high income countries exhibiting the smallest increase in the percentage of urban population, while the less densely-populated lower income countries exhibited the biggest increase in their percentages of urban population.
#
# __2. How many countries are in each region? How many people in each region?__
#
#     Countries per region:
#     East Asia & Pacific: 36
#     Europe & Central Asia: 56
#     Latin America & Caribbean: 38
#     Middle East & North Africa: 21
#     North America: 3
#     South Asia: 8
#     Sub-Saharan Africa: 48
#
#     People per region:
#     East Asia & Pacific: 2,057,032,608
#     Europe & Central Asia: 863,676,818
#     Latin America & Caribbean: 540,028,983
#     Middle East & North Africa: 323,928,401
#     North America: 319,050,105
#     South Asia: 1,429,513,552
#     Sub-Saharan Africa: 700,219,447
#
#
# __3. How many countries are in each income group? How many people in each group?__
#
#     Countries per income group:
#     High income: 72
#     Low income: 31
#     Lower middle income: 52
#     Upper middle income: 55
#
#     People per income group:
#     High income: 1,061,860,535
#     Low income: 446,026,847
#     Lower middle income: 2,401,753,297
#     Upper middle income: 2,323,809,235
#
# __4. Are features like total population, urban population, and % urban population evenly distributed across all income groups and regions?__
#
#     No, they are not. We can see clear divides between income groups and region when looking at these features.
#
# __5. What is the general trend of features over the timespan in the dataset? Can these trends be defined by region or income group?__
#
#     Please see 'Capstone 1: Statistical Analysis.pdf' for a more in-depth explanation.

# %% [markdown]
# ## Initial Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from IPython import display
from ipywidgets import interact, widgets
from time import sleep
from tqdm import tqdm
import scipy
from scipy import stats
#import scipy.stats
from scipy.stats import ttest_ind
from itertools import combinations

sns.set_style("whitegrid")
sns.set_context("talk")

# %%
# For progress bar on running code:
# for i in tqdm(range(1000)):
#     sleep(0.01)

# %%
# Read in the csv file containing the cleaned data
df = pd.read_csv('Cleaned_Training_Set.csv', header=0)
df = df.drop('Unnamed: 0', axis=1)
df
# Out:
#           country  year   World bank region World bank, 4 income groups 2017  \
# 0     Afghanistan  1972          South Asia                       Low income
# 1     Afghanistan  1973          South Asia                       Low income
# 2     Afghanistan  1974          South Asia                       Low income
# 3     Afghanistan  1975          South Asia                       Low income
# 4     Afghanistan  1976          South Asia                       Low income
# ...           ...   ...                 ...                              ...
# 6466     Zimbabwe  1998  Sub-Saharan Africa                       Low income
# 6467     Zimbabwe  1999  Sub-Saharan Africa                       Low income
# 6468     Zimbabwe  2000  Sub-Saharan Africa                       Low income
# 6469     Zimbabwe  2001  Sub-Saharan Africa                       Low income
# 6470     Zimbabwe  2002  Sub-Saharan Africa                       Low income
#
#       Adjusted savings: mineral depletion (current US$)  \
# 0                                          0.000000e+00
# 1                                          0.000000e+00
# 2                                          0.000000e+00
# 3                                          0.000000e+00
# 4                                          0.000000e+00
# ...                                                 ...
# 6466                                       3.574371e+06
# 6467                                       1.121581e+07
# 6468                                       2.259094e+07
# 6469                                       1.491629e+07
# 6470                                       2.946757e+07
#
#       Adjusted savings: energy depletion (current US$)  Population (Total)  \
# 0                                         2.233065e+07          11644377.0
# 1                                         2.654146e+07          11966352.0
# 2                                         6.606462e+07          12273589.0
# 3                                         6.882184e+07          12551790.0
# 4                                         6.463635e+07          12806810.0
# ...                                                ...                 ...
# 6466                                      2.922644e+06          12229500.0
# 6467                                      0.000000e+00          12384727.0
# 6468                                      1.635434e+06          12503652.0
# 6469                                      2.523939e+07          12586763.0
# 6470                                      6.534920e+06          12640922.0
#
#       Population growth (annual %)  \
# 0                         2.794796
# 1                         2.727531
# 2                         2.535101
# 3                         2.241357
# 4                         2.011378
# ...                            ...
# 6466                      1.513394
# 6467                      1.261295
# 6468                      0.955674
# 6469                      0.662494
# 6470                      0.429362
#
#       Population density (people per sq. km of land area)  \
# 0                                             17.853176
# 1                                             18.346829
# 2                                             18.817885
# 3                                             19.244423
# 4                                             19.635420
# ...                                                 ...
# 6466                                          31.613028
# 6467                                          32.014287
# 6468                                          32.321706
# 6469                                          32.536546
# 6470                                          32.676546
#
#       Rural population (% of total population)  Urban population (% of total)  \
# 0                                      88.0702                        11.9298
# 1                                      87.6208                        12.3792
# 2                                      87.1714                        12.8286
# 3                                      86.7220                        13.2780
# 4                                      86.2426                        13.7574
# ...                                        ...                            ...
# 6466                                   67.0524                        32.9476
# 6467                                   66.6472                        33.3528
# 6468                                   66.2420                        33.7580
# 6469                                   65.8216                        34.1784
# 6470                                   65.4012                        34.5988
#
#       Rural population  Urban population  Urban population growth (annual %)  \
# 0           10255226.0         1389151.0                            6.634620
# 1           10485013.0         1481339.0                            6.425364
# 2           10699059.0         1574530.0                            6.101041
# 3           10885163.0         1666627.0                            5.684501
# 4           11044926.0         1761884.0                            5.558187
# ...                ...               ...                                 ...
# 6466         8200173.0         4029327.0                            2.750848
# 6467         8254074.0         4130653.0                            2.483614
# 6468         8282669.0         4220983.0                            2.163253
# 6469         8284809.0         4301954.0                            1.900130
# 6470         8267315.0         4373607.0                            1.651873
#
#       Urban population 5 years in the future
# 0                                    1855690
# 1                                    1942479
# 2                                    2014500
# 3                                    2066033
# 4                                    2064276
# ...                                      ...
# 6466                                 4438019
# 6467                                 4498365
# 6468                                 4558017
# 6469                                 4620705
# 6470                                 4684302
#
# [6471 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6471 entries, 0 to 6470
# Data columns (total 15 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   country                                              6471 non-null   object
#  1   year                                                 6471 non-null   int64
#  2   World bank region                                    6471 non-null   object
#  3   World bank, 4 income groups 2017                     6471 non-null   object
#  4   Adjusted savings: mineral depletion (current US$)    6471 non-null   float64
#  5   Adjusted savings: energy depletion (current US$)     6471 non-null   float64
#  6   Population (Total)                                   6471 non-null   float64
#  7   Population growth (annual %)                         6471 non-null   float64
#  8   Population density (people per sq. km of land area)  6471 non-null   float64
#  9   Rural population (% of total population)             6471 non-null   float64
#  10  Urban population (% of total)                        6471 non-null   float64
#  11  Rural population                                     6471 non-null   float64
#  12  Urban population                                     6471 non-null   float64
#  13  Urban population growth (annual %)                   6471 non-null   float64
#  14  Urban population 5 years in the future               6471 non-null   int64
# dtypes: float64(10), int64(2), object(3)
# memory usage: 758.4+ KB

# %%
df.describe()
# Out:
#               year  Adjusted savings: mineral depletion (current US$)  \
# count  6471.000000                                       6.471000e+03
# mean   1987.033380                                       7.351437e+07
# std       8.949392                                       3.185078e+08
# min    1972.000000                                       0.000000e+00
# 25%    1979.000000                                       0.000000e+00
# 50%    1987.000000                                       0.000000e+00
# 75%    1995.000000                                       9.529645e+06
# max    2002.000000                                       5.345889e+09
#
#        Adjusted savings: energy depletion (current US$)  Population (Total)  \
# count                                      6.471000e+03        6.471000e+03
# mean                                       1.390014e+09        2.397868e+07
# std                                        5.940447e+09        9.818894e+07
# min                                        0.000000e+00        5.924000e+03
# 25%                                        0.000000e+00        5.793925e+05
# 50%                                        0.000000e+00        4.359166e+06
# 75%                                        2.182143e+08        1.337768e+07
# max                                        1.218202e+11        1.280400e+09
#
#        Population growth (annual %)  \
# count                   6471.000000
# mean                       1.839108
# std                        1.624394
# min                       -7.597309
# 25%                        0.744508
# 50%                        1.842203
# 75%                        2.721474
# max                       17.107347
#
#        Population density (people per sq. km of land area)  \
# count                                        6471.000000
# mean                                          283.575748
# std                                          1370.594462
# min                                             0.000000
# 25%                                            19.043229
# 50%                                            56.593926
# 75%                                           139.962512
# max                                         16326.500000
#
#        Rural population (% of total population)  \
# count                               6471.000000
# mean                                  50.184895
# std                                   24.869344
# min                                    0.000000
# 25%                                   30.845400
# 50%                                   50.948800
# 75%                                   70.812700
# max                                   97.283600
#
#        Urban population (% of total)  Rural population  Urban population  \
# count                    6471.000000      6.471000e+03      6.471000e+03
# mean                       49.815105      1.380235e+07      1.017633e+07
# std                        24.869344      7.074894e+07      3.169468e+07
# min                         2.716400      0.000000e+00      1.757000e+03
# 25%                        29.187300      2.436050e+05      2.284950e+05
# 50%                        49.051200      2.100014e+06      1.693451e+06
# 75%                        69.154600      6.770802e+06      6.337645e+06
# max                       100.000000      8.360900e+08      4.934021e+08
#
#        Urban population growth (annual %)  \
# count                         6471.000000
# mean                             2.958250
# std                              2.543876
# min                            -42.301838
# 25%                              1.232784
# 50%                              2.710241
# 75%                              4.332735
# max                             20.196932
#
#        Urban population 5 years in the future
# count                            6.471000e+03
# mean                             1.147803e+07
# std                              3.669893e+07
# min                              2.140000e+03
# 25%                              2.664490e+05
# 50%                              1.975930e+06
# 75%                              6.912087e+06
# max                              5.957315e+08

# %% [markdown]
# ## Investigating the 0's

# %%
# We want to investigate the data points where anything besides 'Adjusted savings...' is 0
df.loc[df['Population density (people per sq. km of land area)'].idxmin()]
# Out:
# country                                                       South Sudan
# year                                                                 1972
# World bank region                                      Sub-Saharan Africa
# World bank, 4 income groups 2017                               Low income
# Adjusted savings: mineral depletion (current US$)                       0
# Adjusted savings: energy depletion (current US$)                        0
# Population (Total)                                            3.82378e+06
# Population growth (annual %)                                      2.38617
# Population density (people per sq. km of land area)                     0
# Rural population (% of total population)                          91.3898
# Urban population (% of total)                                      8.6102
# Rural population                                              3.49455e+06
# Urban population                                                   329235
# Urban population growth (annual %)                                2.25371
# Urban population 5 years in the future                             370351
# Name: 5280, dtype: object

# %%
df.loc[df['Rural population (% of total population)'].idxmin()]
# Out:
# country                                                      Bermuda
# year                                                            1972
# World bank region                                      North America
# World bank, 4 income groups 2017                         High income
# Adjusted savings: mineral depletion (current US$)                  0
# Adjusted savings: energy depletion (current US$)                   0
# Population (Total)                                             54200
# Population growth (annual %)                               -0.732601
# Population density (people per sq. km of land area)             1084
# Rural population (% of total population)                           0
# Urban population (% of total)                                    100
# Rural population                                                   0
# Urban population                                               54200
# Urban population growth (annual %)                         -0.735297
# Urban population 5 years in the future                         53400
# Name: 651, dtype: object

# %% [markdown]
# ## Finding the Min and Max of Variables

# %%
# Minimum of each variable
print(df.min())
# Out:
# country                                                        Afghanistan
# year                                                                  1972
# World bank region                                      East Asia & Pacific
# World bank, 4 income groups 2017                               High income
# Adjusted savings: mineral depletion (current US$)                        0
# Adjusted savings: energy depletion (current US$)                         0
# Population (Total)                                                    5924
# Population growth (annual %)                                      -7.59731
# Population density (people per sq. km of land area)                      0
# Rural population (% of total population)                                 0
# Urban population (% of total)                                       2.7164
# Rural population                                                         0
# Urban population                                                      1757
# Urban population growth (annual %)                                -42.3018
# Urban population 5 years in the future                                2140
# dtype: object

# %%
# Maximum of each variable 
print(df.max())
# Out:
# country                                                           Zimbabwe
# year                                                                  2002
# World bank region                                       Sub-Saharan Africa
# World bank, 4 income groups 2017                       Upper middle income
# Adjusted savings: mineral depletion (current US$)              5.34589e+09
# Adjusted savings: energy depletion (current US$)                1.2182e+11
# Population (Total)                                              1.2804e+09
# Population growth (annual %)                                       17.1073
# Population density (people per sq. km of land area)                16326.5
# Rural population (% of total population)                           97.2836
# Urban population (% of total)                                          100
# Rural population                                                8.3609e+08
# Urban population                                               4.93402e+08
# Urban population growth (annual %)                                 20.1969
# Urban population 5 years in the future                           595731464
# dtype: object

# %% [markdown]
# ### Looking at Total Population

# %%
# We can find the data point where the total population is the maximum in our data set, and we can also view the 
# other stats tied to this observation (defined as country and year).
df.loc[df['Population (Total)'].idxmax()]
# Out:
# country                                                              China
# year                                                                  2002
# World bank region                                      East Asia & Pacific
# World bank, 4 income groups 2017                       Upper middle income
# Adjusted savings: mineral depletion (current US$)              2.20044e+09
# Adjusted savings: energy depletion (current US$)               1.82854e+10
# Population (Total)                                              1.2804e+09
# Population growth (annual %)                                          0.67
# Population density (people per sq. km of land area)                137.272
# Rural population (% of total population)                            61.465
# Urban population (% of total)                                       38.535
# Rural population                                               7.86998e+08
# Urban population                                               4.93402e+08
# Urban population growth (annual %)                                 4.17969
# Urban population 5 years in the future                           595731464
# Name: 1270, dtype: object

# %%
# We can clean it up so that we are only seeing the country, year, and value of the feature that we are interested in.
max_total_pop = (df.loc[df['Population (Total)'].idxmax()]['country'], 
                 df.loc[df['Population (Total)'].idxmax()]['year'], 
                 df.loc[df['Population (Total)'].idxmax()]['Population (Total)'])
max_total_pop
# Out:
# ('China', 2002, 1280400000.0)

# %%
# Here we find the minimum
df.loc[df['Population (Total)'].idxmin()]
# Out:
# country                                                 Turks and Caicos Islands
# year                                                                        1972
# World bank region                                      Latin America & Caribbean
# World bank, 4 income groups 2017                                     High income
# Adjusted savings: mineral depletion (current US$)                              0
# Adjusted savings: energy depletion (current US$)                               0
# Population (Total)                                                          5924
# Population growth (annual %)                                              2.9812
# Population density (people per sq. km of land area)                      6.23579
# Rural population (% of total population)                                 48.1112
# Urban population (% of total)                                            51.8888
# Rural population                                                            2850
# Urban population                                                            3074
# Urban population growth (annual %)                                       3.74526
# Urban population 5 years in the future                                      3714
# Name: 5962, dtype: object

# %%
# The country, year, and value of our feature minimum
min_total_pop = (df.loc[df['Population (Total)'].idxmin()]['country'], 
                 df.loc[df['Population (Total)'].idxmin()]['year'], 
                 df.loc[df['Population (Total)'].idxmin()]['Population (Total)'])
min_total_pop
# Out:
# ('Turks and Caicos Islands', 1972, 5924.0)

# %%
# But what if we want the minimum of a certain year, such as 2002 for example?
df_2002 = df[df.year == 2002]
df_2002
df_2002.loc[df_2002['Population (Total)'].idxmin()]
# Out:
# country                                                             Tuvalu
# year                                                                  2002
# World bank region                                      East Asia & Pacific
# World bank, 4 income groups 2017                       Upper middle income
# Adjusted savings: mineral depletion (current US$)                        0
# Adjusted savings: energy depletion (current US$)                         0
# Population (Total)                                                    9530
# Population growth (annual %)                                      0.621022
# Population density (people per sq. km of land area)                317.667
# Rural population (% of total population)                           53.1572
# Urban population (% of total)                                      46.8428
# Rural population                                                      5066
# Urban population                                                      4464
# Urban population growth (annual %)                                 1.51227
# Urban population 5 years in the future                                4775
# Name: 6023, dtype: object

# %%
# Here we save the total world population and total urban population for use later. 
world_pop_tot_2002 = df['Population (Total)'][df.year == 2002].sum()
print('The world population in 2002 was {:.0f}.'.format(world_pop_tot_2002))
urban_pop_2002 = df['Urban population'][df.year == 2002].sum()
print('The total urban population in 2002 was {:.0f}.'.format(urban_pop_2002))
# Out:
# The world population in 2002 was 6233449914.
# The total urban population in 2002 was 2971287694.

# %%
total_pop_1972 = df[df['year'] == 1972].sort_values('Population (Total)', ascending=False)
total_pop_1972
# Out:
#                        country  year          World bank region  \
# 1240                     China  1972        East Asia & Pacific
# 2635                     India  1972                 South Asia
# 6148             United States  1972              North America
# 4802        Russian Federation  1972      Europe & Central Asia
# 2666                 Indonesia  1972        East Asia & Pacific
# ...                        ...   ...                        ...
# 4337  Northern Mariana Islands  1972        East Asia & Pacific
# 4461                     Palau  1972        East Asia & Pacific
# 1085            Cayman Islands  1972  Latin America & Caribbean
# 5993                    Tuvalu  1972        East Asia & Pacific
# 5962  Turks and Caicos Islands  1972  Latin America & Caribbean
#
#      World bank, 4 income groups 2017  \
# 1240              Upper middle income
# 2635              Lower middle income
# 6148                      High income
# 4802              Upper middle income
# 2666              Lower middle income
# ...                               ...
# 4337                      High income
# 4461                      High income
# 1085                      High income
# 5993              Upper middle income
# 5962                      High income
#
#       Adjusted savings: mineral depletion (current US$)  \
# 1240                                       1.247649e+08
# 2635                                       9.884152e+07
# 6148                                       7.294271e+08
# 4802                                       0.000000e+00
# 2666                                       2.170118e+07
# ...                                                 ...
# 4337                                       0.000000e+00
# 4461                                       0.000000e+00
# 1085                                       0.000000e+00
# 5993                                       0.000000e+00
# 5962                                       0.000000e+00
#
#       Adjusted savings: energy depletion (current US$)  Population (Total)  \
# 1240                                      3.684485e+08         862030000.0
# 2635                                      1.521309e+08         580798773.0
# 6148                                      8.433588e+09         209896000.0
# 4802                                      0.000000e+00         131909000.0
# 2666                                      3.843327e+08         119974444.0
# ...                                                ...                 ...
# 4337                                      0.000000e+00             14142.0
# 4461                                      0.000000e+00             11853.0
# 1085                                      0.000000e+00             10137.0
# 5993                                      0.000000e+00              7459.0
# 5962                                      0.000000e+00              5924.0
#
#       Population growth (annual %)  \
# 1240                      2.457357
# 2635                      2.262619
# 6148                      1.070523
# 4802                      0.573246
# 2666                      2.513896
# ...                            ...
# 4337                      3.482366
# 4461                      1.675993
# 1085                      5.620140
# 5993                      1.078323
# 5962                      2.981204
#
#       Population density (people per sq. km of land area)  \
# 1240                                          92.418614
# 2635                                         195.345327
# 6148                                          22.917012
# 4802                                           8.048164
# 2666                                          66.226778
# ...                                                 ...
# 4337                                         125.039130
# 4461                                          37.510870
# 1085                                          42.237500
# 5993                                         248.633333
# 5962                                           6.235789
#
#       Rural population (% of total population)  Urban population (% of total)  \
# 1240                                   82.6000                        17.4000
# 2635                                   79.6112                        20.3888
# 6148                                   26.3776                        73.6224
# 4802                                   35.9466                        64.0534
# 2666                                   82.0306                        17.9694
# ...                                        ...                            ...
# 4337                                   25.7412                        74.2588
# 4461                                   39.7158                        60.2842
# 1085                                    0.0000                       100.0000
# 5993                                   76.4470                        23.5530
# 5962                                   48.1112                        51.8888
#
#       Rural population  Urban population  Urban population growth (annual %)  \
# 1240       712036780.0       149993220.0                            2.457357
# 2635       462380873.0       118417900.0                            3.816655
# 6148        55365527.0       154530473.0                            1.084378
# 4802        47416801.0        84492199.0                            1.816158
# 2666        98415756.0        21558688.0                            5.045479
# ...                ...               ...                                 ...
# 4337            3640.0           10502.0                            6.348531
# 4461            4708.0            7145.0                            2.136017
# 1085               0.0           10137.0                            5.620140
# 5993            5702.0            1757.0                            4.243589
# 5962            2850.0            3074.0                            3.745260
#
#       Urban population 5 years in the future
# 1240                               171550310
# 2635                               143676074
# 6148                               162287512
# 4802                                92216733
# 2666                                27705778
# ...                                      ...
# 4337                                   12700
# 4461                                    7543
# 1085                                   13840
# 5993                                    2140
# 5962                                    3714
#
# [208 rows x 15 columns]

# %%
total_pop_2002 = df[df['year'] == 2002].sort_values('Population (Total)', ascending=False)
total_pop_2002
# Out:
#                        country  year          World bank region  \
# 1270                     China  2002        East Asia & Pacific
# 2665                     India  2002                 South Asia
# 6178             United States  2002              North America
# 2696                 Indonesia  2002        East Asia & Pacific
# 836                     Brazil  2002  Latin America & Caribbean
# ...                        ...   ...                        ...
# 3933                    Monaco  2002      Europe & Central Asia
# 4925                San Marino  2002      Europe & Central Asia
# 5992  Turks and Caicos Islands  2002  Latin America & Caribbean
# 4491                     Palau  2002        East Asia & Pacific
# 6023                    Tuvalu  2002        East Asia & Pacific
#
#      World bank, 4 income groups 2017  \
# 1270              Upper middle income
# 2665              Lower middle income
# 6178                      High income
# 2696              Lower middle income
# 836               Upper middle income
# ...                               ...
# 3933                      High income
# 4925                      High income
# 5992                      High income
# 4491                      High income
# 6023              Upper middle income
#
#       Adjusted savings: mineral depletion (current US$)  \
# 1270                                       2.200444e+09
# 2665                                       1.086572e+09
# 6178                                       6.282125e+08
# 2696                                       1.625153e+09
# 836                                        3.172173e+09
# ...                                                 ...
# 3933                                       0.000000e+00
# 4925                                       0.000000e+00
# 5992                                       0.000000e+00
# 4491                                       0.000000e+00
# 6023                                       0.000000e+00
#
#       Adjusted savings: energy depletion (current US$)  Population (Total)  \
# 1270                                      1.828545e+10        1.280400e+09
# 2665                                      5.968493e+09        1.076706e+09
# 6178                                      4.174834e+10        2.876252e+08
# 2696                                      9.120971e+09        2.150383e+08
# 836                                       7.382715e+09        1.793938e+08
# ...                                                ...                 ...
# 3933                                      0.000000e+00        3.265300e+04
# 4925                                      0.000000e+00        2.806400e+04
# 5992                                      0.000000e+00        2.174000e+04
# 4491                                      0.000000e+00        1.957500e+04
# 6023                                      0.000000e+00        9.530000e+03
#
#       Population growth (annual %)  \
# 1270                      0.670000
# 2665                      1.610819
# 6178                      0.927797
# 2696                      1.436958
# 836                       1.361313
# ...                            ...
# 3933                      0.882825
# 4925                      2.150233
# 5992                      7.416459
# 4491                      0.877401
# 6023                      0.621022
#
#       Population density (people per sq. km of land area)  \
# 1270                                         137.271700
# 2665                                         362.138216
# 6178                                          31.393550
# 2696                                         118.702719
# 836                                           21.206391
# ...                                                 ...
# 3933                                       16326.500000
# 4925                                         467.733333
# 5992                                          22.884211
# 4491                                          42.554348
# 6023                                         317.666667
#
#       Rural population (% of total population)  Urban population (% of total)  \
# 1270                                   61.4650                        38.5350
# 2665                                   71.7058                        28.2942
# 6178                                   20.2542                        79.7458
# 2696                                   56.4240                        43.5760
# 836                                    18.1512                        81.8488
# ...                                        ...                            ...
# 3933                                    0.0000                       100.0000
# 4925                                    6.3284                        93.6716
# 5992                                   13.4076                        86.5924
# 4491                                   26.9422                        73.0578
# 6023                                   53.1572                        46.8428
#
#       Rural population  Urban population  Urban population growth (annual %)  \
# 1270       786997860.0       493402140.0                            4.179688
# 2665       772060452.0       304645271.0                            2.725361
# 6178        58256182.0       229369011.0                            1.340456
# 2696       121333202.0        93705083.0                            3.259506
# 836         32562122.0       146831646.0                            1.763347
# ...                ...               ...                                 ...
# 3933               0.0           32653.0                            0.882825
# 4925            1776.0           26288.0                            2.273831
# 5992            2915.0           18825.0                            8.604118
# 4491            5274.0           14301.0                            3.016874
# 6023            5066.0            4464.0                            1.512273
#
#       Urban population 5 years in the future
# 1270                               595731464
# 2665                               346720162
# 6178                               244888320
# 2696                               109785533
# 836                                158522837
# ...                                      ...
# 3933                                   35013
# 4925                                   28569
# 5992                                   26088
# 4491                                   16088
# 6023                                    4775
#
# [210 rows x 15 columns]

# %%
# Using a histogram, we can see how the total population is distributed, and we can also see 2 outliers above the
# 1,000,000,000 mark--China and India.
_ = plt.hist(df['Population (Total)'][df['year'] == 1972], histtype='step', bins=500)
plt.show()

# %%
# Now let's view the distribution while excluding our 2 most extreme outliers
_ = plt.xlim(0, 2.25e8)
_ = plt.hist(df['Population (Total)'][df['year'] == 1972], histtype='step', bins=500)
plt.show()

# %%
# Using a histogram, we can see how the total population is distributed, and we can also see 2 outliers above the
# 1,000,000,000 mark--China and India.
_ = plt.hist(df['Population (Total)'][df['year'] == 2002], histtype='step', bins=500)
plt.show()

# %%
# Now let's view the distribution while excluding our 2 most extreme outliers
_ = plt.xlim(0, 1.5e8)
_ = plt.hist(df['Population (Total)'][df['year'] == 2002], histtype='step', bins=500)
plt.show()

# %%
# What percentage of our countries had a population below the mean in 1972?
scipy.stats.percentileofscore(df['Population (Total)'][df['year'] == 1972], 
                              np.mean(df['Population (Total)'][df['year'] == 1972]))
# Out:
# 84.13461538461539

# %%
# What percentage of our countries had a population below the mean in 2002?
scipy.stats.percentileofscore(df['Population (Total)'][df['year'] == 2002], 
                              np.mean(df['Population (Total)'][df['year'] == 2002]))
# Out:
# 83.33333333333333

# %% [markdown]
# Above, we see that over 80% of countries in our dataset fall below the mean in both 1972 and 2002. This shows us just how much our two largest outliers skew the mean.

# %% [markdown]
# ### Looking at Urban Population

# %%
# Information about our data point where 'Urban population' is the maximum in the dataset
df.loc[df['Urban population'].idxmax()]
# Out:
# country                                                              China
# year                                                                  2002
# World bank region                                      East Asia & Pacific
# World bank, 4 income groups 2017                       Upper middle income
# Adjusted savings: mineral depletion (current US$)              2.20044e+09
# Adjusted savings: energy depletion (current US$)               1.82854e+10
# Population (Total)                                              1.2804e+09
# Population growth (annual %)                                          0.67
# Population density (people per sq. km of land area)                137.272
# Rural population (% of total population)                            61.465
# Urban population (% of total)                                       38.535
# Rural population                                               7.86998e+08
# Urban population                                               4.93402e+08
# Urban population growth (annual %)                                 4.17969
# Urban population 5 years in the future                           595731464
# Name: 1270, dtype: object

# %%
# Information about our data point where 'Urban population' is the minimum in the dataset
df.loc[df['Urban population'].idxmin()]
# Out:
# country                                                             Tuvalu
# year                                                                  1972
# World bank region                                      East Asia & Pacific
# World bank, 4 income groups 2017                       Upper middle income
# Adjusted savings: mineral depletion (current US$)                        0
# Adjusted savings: energy depletion (current US$)                         0
# Population (Total)                                                    7459
# Population growth (annual %)                                       1.07832
# Population density (people per sq. km of land area)                248.633
# Rural population (% of total population)                            76.447
# Urban population (% of total)                                       23.553
# Rural population                                                      5702
# Urban population                                                      1757
# Urban population growth (annual %)                                 4.24359
# Urban population 5 years in the future                                2140
# Name: 5993, dtype: object

# %%
# Because the idxmin value for urban population in the dataset occurred in the year 1972, we can assume that in 
# the years following, the urban population of Tuvalu or any other country was 1757 or greater.

# %%
# What about the country with the minimum urban population in the last year of our dataset, in 2002?
df_2002 = df[df.year == 2002]
df_2002
df_2002.loc[df_2002['Urban population'].idxmin()]
# Out:
# country                                                             Tuvalu
# year                                                                  2002
# World bank region                                      East Asia & Pacific
# World bank, 4 income groups 2017                       Upper middle income
# Adjusted savings: mineral depletion (current US$)                        0
# Adjusted savings: energy depletion (current US$)                         0
# Population (Total)                                                    9530
# Population growth (annual %)                                      0.621022
# Population density (people per sq. km of land area)                317.667
# Rural population (% of total population)                           53.1572
# Urban population (% of total)                                      46.8428
# Rural population                                                      5066
# Urban population                                                      4464
# Urban population growth (annual %)                                 1.51227
# Urban population 5 years in the future                                4775
# Name: 6023, dtype: object

# %%
urban_pop_1972 = df[df['year'] == 1972].sort_values('Urban population', ascending=False)
urban_pop_1972
# Out:
#                        country  year          World bank region  \
# 6148             United States  1972              North America
# 1240                     China  1972        East Asia & Pacific
# 2635                     India  1972                 South Asia
# 4802        Russian Federation  1972      Europe & Central Asia
# 2914                     Japan  1972        East Asia & Pacific
# ...                        ...   ...                        ...
# 1085            Cayman Islands  1972  Latin America & Caribbean
# 4461                     Palau  1972        East Asia & Pacific
# 3376             Liechtenstein  1972      Europe & Central Asia
# 5962  Turks and Caicos Islands  1972  Latin America & Caribbean
# 5993                    Tuvalu  1972        East Asia & Pacific
#
#      World bank, 4 income groups 2017  \
# 6148                      High income
# 1240              Upper middle income
# 2635              Lower middle income
# 4802              Upper middle income
# 2914                      High income
# ...                               ...
# 1085                      High income
# 4461                      High income
# 3376                      High income
# 5962                      High income
# 5993              Upper middle income
#
#       Adjusted savings: mineral depletion (current US$)  \
# 6148                                       7.294271e+08
# 1240                                       1.247649e+08
# 2635                                       9.884152e+07
# 4802                                       0.000000e+00
# 2914                                       5.055072e+07
# ...                                                 ...
# 1085                                       0.000000e+00
# 4461                                       0.000000e+00
# 3376                                       0.000000e+00
# 5962                                       0.000000e+00
# 5993                                       0.000000e+00
#
#       Adjusted savings: energy depletion (current US$)  Population (Total)  \
# 6148                                      8.433588e+09         209896000.0
# 1240                                      3.684485e+08         862030000.0
# 2635                                      1.521309e+08         580798773.0
# 4802                                      0.000000e+00         131909000.0
# 2914                                      2.587987e+07         107188000.0
# ...                                                ...                 ...
# 1085                                      0.000000e+00             10137.0
# 4461                                      0.000000e+00             11853.0
# 3376                                      0.000000e+00             22153.0
# 5962                                      0.000000e+00              5924.0
# 5993                                      0.000000e+00              7459.0
#
#       Population growth (annual %)  \
# 6148                      1.070523
# 1240                      2.457357
# 2635                      2.262619
# 4802                      0.573246
# 2914                      1.400779
# ...                            ...
# 1085                      5.620140
# 4461                      1.675993
# 3376                      1.946323
# 5962                      2.981204
# 5993                      1.078323
#
#       Population density (people per sq. km of land area)  \
# 6148                                          22.917012
# 1240                                          92.418614
# 2635                                         195.345327
# 4802                                           8.048164
# 2914                                         292.384070
# ...                                                 ...
# 1085                                          42.237500
# 4461                                          37.510870
# 3376                                         138.456250
# 5962                                           6.235789
# 5993                                         248.633333
#
#       Rural population (% of total population)  Urban population (% of total)  \
# 6148                                   26.3776                        73.6224
# 1240                                   82.6000                        17.4000
# 2635                                   79.6112                        20.3888
# 4802                                   35.9466                        64.0534
# 2914                                   26.5874                        73.4126
# ...                                        ...                            ...
# 1085                                    0.0000                       100.0000
# 4461                                   39.7158                        60.2842
# 3376                                   81.5986                        18.4014
# 5962                                   48.1112                        51.8888
# 5993                                   76.4470                        23.5530
#
#       Rural population  Urban population  Urban population growth (annual %)  \
# 6148        55365527.0       154530473.0                            1.084378
# 1240       712036780.0       149993220.0                            2.457357
# 2635       462380873.0       118417900.0                            3.816655
# 4802        47416801.0        84492199.0                            1.816158
# 2914        28498502.0        78689498.0                            2.452157
# ...                ...               ...                                 ...
# 1085               0.0           10137.0                            5.620140
# 4461            4708.0            7145.0                            2.136017
# 3376           18077.0            4076.0                            1.807204
# 5962            2850.0            3074.0                            3.745260
# 5993            5702.0            1757.0                            4.243589
#
#       Urban population 5 years in the future
# 6148                               162287512
# 1240                               171550310
# 2635                               143676074
# 4802                                92216733
# 2914                                86421562
# ...                                      ...
# 1085                                   13840
# 4461                                    7543
# 3376                                    4474
# 5962                                    3714
# 5993                                    2140
#
# [208 rows x 15 columns]

# %%
urban_pop_2002 = df[df['year'] == 2002].sort_values('Urban population', ascending=False)
urban_pop_2002
# Out:
#                   country  year          World bank region  \
# 1270                China  2002        East Asia & Pacific
# 2665                India  2002                 South Asia
# 6178        United States  2002              North America
# 836                Brazil  2002  Latin America & Caribbean
# 4832   Russian Federation  2002      Europe & Central Asia
# ...                   ...   ...                        ...
# 1952       Faeroe Islands  2002      Europe & Central Asia
# 5403  St. Kitts and Nevis  2002  Latin America & Caribbean
# 4491                Palau  2002        East Asia & Pacific
# 3406        Liechtenstein  2002      Europe & Central Asia
# 6023               Tuvalu  2002        East Asia & Pacific
#
#      World bank, 4 income groups 2017  \
# 1270              Upper middle income
# 2665              Lower middle income
# 6178                      High income
# 836               Upper middle income
# 4832              Upper middle income
# ...                               ...
# 1952                      High income
# 5403                      High income
# 4491                      High income
# 3406                      High income
# 6023              Upper middle income
#
#       Adjusted savings: mineral depletion (current US$)  \
# 1270                                       2.200444e+09
# 2665                                       1.086572e+09
# 6178                                       6.282125e+08
# 836                                        3.172173e+09
# 4832                                       7.723306e+08
# ...                                                 ...
# 1952                                       0.000000e+00
# 5403                                       0.000000e+00
# 4491                                       0.000000e+00
# 3406                                       0.000000e+00
# 6023                                       0.000000e+00
#
#       Adjusted savings: energy depletion (current US$)  Population (Total)  \
# 1270                                      1.828545e+10        1.280400e+09
# 2665                                      5.968493e+09        1.076706e+09
# 6178                                      4.174834e+10        2.876252e+08
# 836                                       7.382715e+09        1.793938e+08
# 4832                                      5.429729e+10        1.454080e+08
# ...                                                ...                 ...
# 1952                                      0.000000e+00        4.775100e+04
# 5403                                      0.000000e+00        4.693400e+04
# 4491                                      0.000000e+00        1.957500e+04
# 3406                                      0.000000e+00        3.382100e+04
# 6023                                      0.000000e+00        9.530000e+03
#
#       Population growth (annual %)  \
# 1270                      0.670000
# 2665                      1.610819
# 6178                      0.927797
# 836                       1.361313
# 4832                     -0.390165
# ...                            ...
# 1952                      1.298418
# 5403                      1.545958
# 4491                      0.877401
# 3406                      1.028302
# 6023                      0.621022
#
#       Population density (people per sq. km of land area)  \
# 1270                                         137.271700
# 2665                                         362.138216
# 6178                                          31.393550
# 836                                           21.206391
# 4832                                           8.876660
# ...                                                 ...
# 1952                                          34.205587
# 5403                                         180.515385
# 4491                                          42.554348
# 3406                                         211.381250
# 6023                                         317.666667
#
#       Rural population (% of total population)  Urban population (% of total)  \
# 1270                                   61.4650                        38.5350
# 2665                                   71.7058                        28.2942
# 6178                                   20.2542                        79.7458
# 836                                    18.1512                        81.8488
# 4832                                   26.8180                        73.1820
# ...                                        ...                            ...
# 1952                                   62.2854                        37.7146
# 5403                                   67.5020                        32.4980
# 4491                                   26.9422                        73.0578
# 3406                                   85.0296                        14.9704
# 6023                                   53.1572                        46.8428
#
#       Rural population  Urban population  Urban population growth (annual %)  \
# 1270       786997860.0       493402140.0                            4.179688
# 2665       772060452.0       304645271.0                            2.725361
# 6178        58256182.0       229369011.0                            1.340456
# 836         32562122.0       146831646.0                            1.763347
# 4832        38995526.0       106412507.0                           -0.504882
# ...                ...               ...                                 ...
# 1952           29742.0           18009.0                            3.141738
# 5403           31681.0           15253.0                            1.120792
# 4491            5274.0           14301.0                            3.016874
# 3406           28758.0            5063.0                            0.495002
# 6023            5066.0            4464.0                            1.512273
#
#       Urban population 5 years in the future
# 1270                               595731464
# 2665                               346720162
# 6178                               244888320
# 836                                158522837
# 4832                               104054827
# ...                                      ...
# 1952                                   19940
# 5403                                   16164
# 4491                                   16088
# 3406                                    5161
# 6023                                    4775
#
# [210 rows x 15 columns]

# %%
urban_pop_perc_1972 = df[df['year'] == 1972].sort_values('Urban population (% of total)', ascending=False)
urban_pop_perc_1972
# Out:
#                country  year          World bank region  \
# 1085    Cayman Islands  1972  Latin America & Caribbean
# 5094         Singapore  1972        East Asia & Pacific
# 651            Bermuda  1972              North America
# 3903            Monaco  1972      Europe & Central Asia
# 3469  Macao SAR, China  1972        East Asia & Pacific
# ...                ...   ...                        ...
# 3562            Malawi  1972         Sub-Saharan Africa
# 899       Burkina Faso  1972         Sub-Saharan Africa
# 4120             Nepal  1972                 South Asia
# 4833            Rwanda  1972         Sub-Saharan Africa
# 930            Burundi  1972         Sub-Saharan Africa
#
#      World bank, 4 income groups 2017  \
# 1085                      High income
# 5094                      High income
# 651                       High income
# 3903                      High income
# 3469                      High income
# ...                               ...
# 3562                       Low income
# 899                        Low income
# 4120                       Low income
# 4833                       Low income
# 930                        Low income
#
#       Adjusted savings: mineral depletion (current US$)  \
# 1085                                                0.0
# 5094                                                0.0
# 651                                                 0.0
# 3903                                                0.0
# 3469                                                0.0
# ...                                                 ...
# 3562                                                0.0
# 899                                                 0.0
# 4120                                                0.0
# 4833                                                0.0
# 930                                                 0.0
#
#       Adjusted savings: energy depletion (current US$)  Population (Total)  \
# 1085                                      0.000000e+00             10137.0
# 5094                                      0.000000e+00           2152400.0
# 651                                       0.000000e+00             54200.0
# 3903                                      7.453738e+07             24052.0
# 3469                                      0.000000e+00            254282.0
# ...                                                ...                 ...
# 3562                                      0.000000e+00           4812216.0
# 899                                       0.000000e+00           5825171.0
# 4120                                      0.000000e+00          12060891.0
# 4833                                      7.414104e+03           3983659.0
# 930                                       0.000000e+00           3547335.0
#
#       Population growth (annual %)  \
# 1085                      5.620140
# 5094                      1.852209
# 651                      -0.732601
# 3903                      1.381527
# 3469                      0.157823
# ...                            ...
# 3562                      3.081393
# 899                       1.762899
# 4120                      2.133512
# 4833                      2.937785
# 930                       1.126657
#
#       Population density (people per sq. km of land area)  \
# 1085                                          42.237500
# 5094                                        3212.537313
# 651                                         1084.000000
# 3903                                       12026.000000
# 3469                                        9081.500000
# ...                                                 ...
# 3562                                          51.041748
# 899                                           21.290830
# 4120                                          84.341895
# 4833                                         161.477868
# 930                                          138.136098
#
#       Rural population (% of total population)  Urban population (% of total)  \
# 1085                                    0.0000                       100.0000
# 5094                                    0.0000                       100.0000
# 651                                     0.0000                       100.0000
# 3903                                    0.0000                       100.0000
# 3469                                    2.6244                        97.3756
# ...                                        ...                            ...
# 3562                                   93.3074                         6.6926
# 899                                    94.0136                         5.9864
# 4120                                   95.6944                         4.3056
# 4833                                   96.4856                         3.5144
# 930                                    97.2836                         2.7164
#
#       Rural population  Urban population  Urban population growth (annual %)  \
# 1085               0.0           10137.0                            5.620140
# 5094               0.0         2152400.0                            1.852209
# 651                0.0           54200.0                           -0.735297
# 3903               0.0           24052.0                            1.381527
# 3469            6673.0          247609.0                            0.334553
# ...                ...               ...                                 ...
# 3562         4490154.0          322062.0                            7.977701
# 899          5476453.0          348718.0                            3.791163
# 4120        11541597.0          519294.0                            6.278204
# 4833         3843657.0          140002.0                            7.633239
# 930          3450975.0           96360.0                            7.479154
#
#       Urban population 5 years in the future
# 1085                                   13840
# 5094                                 2325300
# 651                                    53400
# 3903                                   25809
# 3469                                  239201
# ...                                      ...
# 3562                                  465425
# 899                                   469055
# 4120                                  717460
# 4833                                  199273
# 930                                   140255
#
# [208 rows x 15 columns]

# %%
urban_pop_perc_2002 = df[df['year'] == 2002].sort_values('Urban population (% of total)', ascending=False)
urban_pop_perc_2002
# Out:
#                    country  year          World bank region  \
# 3499      Macao SAR, China  2002        East Asia & Pacific
# 681                Bermuda  2002              North America
# 3933                Monaco  2002      Europe & Central Asia
# 1115        Cayman Islands  2002  Latin America & Caribbean
# 2572  Hong Kong SAR, China  2002        East Asia & Pacific
# ...                    ...   ...                        ...
# 4150                 Nepal  2002                 South Asia
# 4553      Papua New Guinea  2002        East Asia & Pacific
# 6054                Uganda  2002         Sub-Saharan Africa
# 5868   Trinidad and Tobago  2002  Latin America & Caribbean
# 960                Burundi  2002         Sub-Saharan Africa
#
#      World bank, 4 income groups 2017  \
# 3499                      High income
# 681                       High income
# 3933                      High income
# 1115                      High income
# 2572                      High income
# ...                               ...
# 4150                       Low income
# 4553              Lower middle income
# 6054                       Low income
# 5868                      High income
# 960                        Low income
#
#       Adjusted savings: mineral depletion (current US$)  \
# 3499                                       0.000000e+00
# 681                                        0.000000e+00
# 3933                                       0.000000e+00
# 1115                                       0.000000e+00
# 2572                                       0.000000e+00
# ...                                                 ...
# 4150                                       0.000000e+00
# 4553                                       3.654597e+08
# 6054                                       0.000000e+00
# 5868                                       0.000000e+00
# 960                                        3.486699e+05
#
#       Adjusted savings: energy depletion (current US$)  Population (Total)  \
# 3499                                      0.000000e+00            444150.0
# 681                                       0.000000e+00             62912.0
# 3933                                      0.000000e+00             32653.0
# 1115                                      0.000000e+00             44742.0
# 2572                                      0.000000e+00           6744100.0
# ...                                                ...                 ...
# 4150                                      5.952135e+04          24102862.0
# 4553                                      2.509640e+08           5660267.0
# 6054                                      0.000000e+00          25943441.0
# 5868                                      1.603527e+09           1277723.0
# 960                                       0.000000e+00           7037727.0
#
#       Population growth (annual %)  \
# 3499                      1.376080
# 681                       0.652758
# 3933                      0.882825
# 1115                      3.236749
# 2572                      0.442847
# ...                            ...
# 4150                      1.875105
# 4553                      2.527963
# 6054                      3.352786
# 5868                      0.421636
# 960                       2.858875
#
#       Population density (people per sq. km of land area)  \
# 3499                                       15862.500000
# 681                                         1258.240000
# 3933                                       16326.500000
# 1115                                         186.425000
# 2572                                        6472.264875
# ...                                                 ...
# 4150                                         168.139951
# 4553                                          12.498933
# 6054                                         129.840554
# 5868                                         249.068811
# 960                                          274.054790
#
#       Rural population (% of total population)  Urban population (% of total)  \
# 3499                                    0.0000                       100.0000
# 681                                     0.0000                       100.0000
# 3933                                    0.0000                       100.0000
# 1115                                    0.0000                       100.0000
# 2572                                    0.0000                       100.0000
# ...                                        ...                            ...
# 4150                                   85.8958                        14.1042
# 4553                                   87.0508                        12.9492
# 6054                                   87.4516                        12.5484
# 5868                                   88.6514                        11.3486
# 960                                    91.3024                         8.6976
#
#       Rural population  Urban population  Urban population growth (annual %)  \
# 3499               0.0          444150.0                            1.376080
# 681                0.0           62912.0                            0.650637
# 3933               0.0           32653.0                            0.882825
# 1115               0.0           44742.0                            3.236749
# 2572               0.0         6744100.0                            0.442847
# ...                ...               ...                                 ...
# 4150        20703346.0         3399516.0                            4.290576
# 4553         4927308.0          732959.0                            1.548854
# 6054        22687954.0         3255487.0                            5.228698
# 5868         1132719.0          145004.0                            2.720034
# 960          6425614.0          612113.0                            5.489275
#
#       Urban population 5 years in the future
# 3499                                  493206
# 681                                    64888
# 3933                                   35013
# 1115                                   51472
# 2572                                 6916300
# ...                                      ...
# 4150                                 4082146
# 4553                                  800535
# 6054                                 4305712
# 5868                                  165731
# 960                                   822987
#
# [210 rows x 15 columns]

# %%
# What percentage of our countries had an urban population below the mean in 1972?
scipy.stats.percentileofscore(df['Urban population'][df['year'] == 1972], 
                              np.mean(df['Urban population'][df['year'] == 1972]))
# Out:
# 82.6923076923077

# %%
# What percentage of our countries had an urban population below the mean in 2002?
scipy.stats.percentileofscore(df['Urban population'][df['year'] == 2002], 
                              np.mean(df['Urban population'][df['year'] == 2002]))
# Out:
# 81.9047619047619

# %% [markdown]
# ## Finding the Mean and Median

# %%
# Inspecting the average of each column in the dataset
df.mean()
# Out:
# year                                                   1.987033e+03
# Adjusted savings: mineral depletion (current US$)      7.351437e+07
# Adjusted savings: energy depletion (current US$)       1.390014e+09
# Population (Total)                                     2.397868e+07
# Population growth (annual %)                           1.839108e+00
# Population density (people per sq. km of land area)    2.835757e+02
# Rural population (% of total population)               5.018490e+01
# Urban population (% of total)                          4.981510e+01
# Rural population                                       1.380235e+07
# Urban population                                       1.017633e+07
# Urban population growth (annual %)                     2.958250e+00
# Urban population 5 years in the future                 1.147803e+07
# dtype: float64

# %%
# Averages for the first year in the dataset
df_avg_1972 = df[df['year'] == 1972].mean()
df_avg_1972
# Out:
# year                                                   1.972000e+03
# Adjusted savings: mineral depletion (current US$)      2.076421e+07
# Adjusted savings: energy depletion (current US$)       1.151294e+08
# Population (Total)                                     1.834937e+07
# Population growth (annual %)                           2.185212e+00
# Population density (people per sq. km of land area)    2.257981e+02
# Rural population (% of total population)               5.684207e+01
# Urban population (% of total)                          4.315793e+01
# Rural population                                       1.155665e+07
# Urban population                                       6.792712e+06
# Urban population growth (annual %)                     3.917874e+00
# Urban population 5 years in the future                 7.721631e+06
# dtype: float64

# %%
# Averages for the final year of the dataset
df_avg_2002 = df[df['year'] == 2002].mean()
df_avg_2002
# Out:
# year                                                   2.002000e+03
# Adjusted savings: mineral depletion (current US$)      9.769403e+07
# Adjusted savings: energy depletion (current US$)       2.075808e+09
# Population (Total)                                     2.968309e+07
# Population growth (annual %)                           1.483484e+00
# Population density (people per sq. km of land area)    3.501765e+02
# Rural population (% of total population)               4.497555e+01
# Urban population (% of total)                          5.502445e+01
# Rural population                                       1.553411e+07
# Urban population                                       1.414899e+07
# Urban population growth (annual %)                     2.190933e+00
# Urban population 5 years in the future                 1.580320e+07
# dtype: float64

# %%
# use averages above to calculate percent growth of each feature over our 31-year timespan 
percent_change_df = (df_avg_2002 - df_avg_1972) / df_avg_1972
percent_change_df
# Out:
# year                                                    0.015213
# Adjusted savings: mineral depletion (current US$)       3.704923
# Adjusted savings: energy depletion (current US$)       17.030219
# Population (Total)                                      0.617663
# Population growth (annual %)                           -0.321126
# Population density (people per sq. km of land area)     0.550839
# Rural population (% of total population)               -0.208763
# Urban population (% of total)                           0.274956
# Rural population                                        0.344170
# Urban population                                        1.082966
# Urban population growth (annual %)                     -0.440785
# Urban population 5 years in the future                  1.046614
# dtype: float64

# %%
# Averages by region over our 31-year dataset observations
avg_by_region = df.groupby('World bank region').mean()
avg_by_region
# Out:
#                                    year  \
# World bank region
# East Asia & Pacific         1987.000000
# Europe & Central Asia       1987.068102
# Latin America & Caribbean   1987.000000
# Middle East & North Africa  1987.157143
# North America               1987.000000
# South Asia                  1987.000000
# Sub-Saharan Africa          1987.000000
#
#                             Adjusted savings: mineral depletion (current US$)  \
# World bank region
# East Asia & Pacific                                              1.264668e+08
# Europe & Central Asia                                            1.774053e+07
# Latin America & Caribbean                                        1.151274e+08
# Middle East & North Africa                                       1.206376e+07
# North America                                                    8.974487e+08
# South Asia                                                       5.886494e+07
# Sub-Saharan Africa                                               4.221434e+07
#
#                             Adjusted savings: energy depletion (current US$)  \
# World bank region
# East Asia & Pacific                                             8.153348e+08
# Europe & Central Asia                                           1.158522e+09
# Latin America & Caribbean                                       8.709898e+08
# Middle East & North Africa                                      4.371660e+09
# North America                                                   1.940805e+10
# South Asia                                                      5.530591e+08
# Sub-Saharan Africa                                              2.501673e+08
#
#                             Population (Total)  Population growth (annual %)  \
# World bank region
# East Asia & Pacific               4.760223e+07                      1.930137
# Europe & Central Asia             1.470134e+07                      0.694433
# Latin America & Caribbean         1.105767e+07                      1.679055
# Middle East & North Africa        1.145419e+07                      3.291377
# North America                     9.074519e+07                      0.902324
# South Asia                        1.340514e+08                      2.255708
# Sub-Saharan Africa                9.985842e+06                      2.593396
#
#                             Population density (people per sq. km of land area)  \
# World bank region
# East Asia & Pacific                                                697.498467
# Europe & Central Asia                                              368.401804
# Latin America & Caribbean                                          121.265863
# Middle East & North Africa                                         143.159353
# North America                                                      392.764018
# South Asia                                                         281.912997
# Sub-Saharan Africa                                                  56.594774
#
#                             Rural population (% of total population)  \
# World bank region
# East Asia & Pacific                                        50.647315
# Europe & Central Asia                                      38.781931
# Latin America & Caribbean                                  44.327834
# Middle East & North Africa                                 33.118671
# North America                                              15.859559
# South Asia                                                 80.719571
# Sub-Saharan Africa                                         71.922280
#
#                             Urban population (% of total)  Rural population  \
# World bank region
# East Asia & Pacific                             49.352685      3.181446e+07
# Europe & Central Asia                           61.218069      4.963905e+06
# Latin America & Caribbean                       55.672166      3.421103e+06
# Middle East & North Africa                      66.881329      5.289811e+06
# North America                                   84.140441      2.189972e+07
# South Asia                                      19.280429      1.012543e+08
# Sub-Saharan Africa                              28.077720      7.239052e+06
#
#                             Urban population  \
# World bank region
# East Asia & Pacific             1.578777e+07
# Europe & Central Asia           9.737432e+06
# Latin America & Caribbean       7.636571e+06
# Middle East & North Africa      6.164379e+06
# North America                   6.884547e+07
# South Asia                      3.279715e+07
# Sub-Saharan Africa              2.746791e+06
#
#                             Urban population growth (annual %)  \
# World bank region
# East Asia & Pacific                                   2.952824
# Europe & Central Asia                                 1.192576
# Latin America & Caribbean                             2.441205
# Middle East & North Africa                            4.217016
# North America                                         1.044027
# South Asia                                            4.533796
# Sub-Saharan Africa                                    4.734341
#
#                             Urban population 5 years in the future
# World bank region
# East Asia & Pacific                                   1.858195e+07
# Europe & Central Asia                                 1.010434e+07
# Latin America & Caribbean                             8.669953e+06
# Middle East & North Africa                            7.243628e+06
# North America                                         7.366721e+07
# South Asia                                            3.837391e+07
# Sub-Saharan Africa                                    3.382479e+06

# %%
# Regional averages for the first year in the dataset
avg_by_region_1972 = df[df['year'] == 1972].groupby('World bank region').mean()
avg_by_region_1972
# Out:
#                               year  \
# World bank region
# East Asia & Pacific         1972.0
# Europe & Central Asia       1972.0
# Latin America & Caribbean   1972.0
# Middle East & North Africa  1972.0
# North America               1972.0
# South Asia                  1972.0
# Sub-Saharan Africa          1972.0
#
#                             Adjusted savings: mineral depletion (current US$)  \
# World bank region
# East Asia & Pacific                                              2.376767e+07
# Europe & Central Asia                                            4.625100e+06
# Latin America & Caribbean                                        2.583094e+07
# Middle East & North Africa                                       9.821005e+05
# North America                                                    4.718819e+08
# South Asia                                                       1.235526e+07
# Sub-Saharan Africa                                               1.444239e+07
#
#                             Adjusted savings: energy depletion (current US$)  \
# World bank region
# East Asia & Pacific                                             2.857678e+07
# Europe & Central Asia                                           2.930498e+07
# Latin America & Caribbean                                       5.943069e+07
# Middle East & North Africa                                      4.303764e+08
# North America                                                   3.143533e+09
# South Asia                                                      2.577967e+07
# Sub-Saharan Africa                                              1.674257e+07
#
#                             Population (Total)  Population growth (annual %)  \
# World bank region
# East Asia & Pacific               3.718566e+07                      2.397581
# Europe & Central Asia             1.347123e+07                      1.273324
# Latin America & Caribbean         7.927806e+06                      2.029657
# Middle East & North Africa        7.393107e+06                      4.149522
# North America                     7.731461e+07                      0.644431
# South Asia                        9.363273e+07                      2.471833
# Sub-Saharan Africa                6.394634e+06                      2.424022
#
#                             Population density (people per sq. km of land area)  \
# World bank region
# East Asia & Pacific                                                533.174422
# Europe & Central Asia                                              317.883183
# Latin America & Caribbean                                          100.036301
# Middle East & North Africa                                          98.205651
# North America                                                      369.778540
# South Asia                                                         190.464194
# Sub-Saharan Africa                                                  39.366668
#
#                             Rural population (% of total population)  \
# World bank region
# East Asia & Pacific                                        56.599411
# Europe & Central Asia                                      44.242091
# Latin America & Caribbean                                  51.034642
# Middle East & North Africa                                 42.020400
# North America                                              16.913600
# South Asia                                                 86.137025
# Sub-Saharan Africa                                         79.847812
#
#                             Urban population (% of total)  Rural population  \
# World bank region
# East Asia & Pacific                             43.400589      2.784846e+07
# Europe & Central Asia                           55.757909      5.154608e+06
# Latin America & Caribbean                       48.965358      3.291312e+06
# Middle East & North Africa                      57.979600      4.123023e+06
# North America                                   83.086400      2.024129e+07
# South Asia                                      13.862975      7.555673e+07
# Sub-Saharan Africa                              20.152188      5.104750e+06
#
#                             Urban population  \
# World bank region
# East Asia & Pacific             9.337198e+06
# Europe & Central Asia           8.316621e+06
# Latin America & Caribbean       4.636494e+06
# Middle East & North Africa      3.270084e+06
# North America                   5.707332e+07
# South Asia                      1.807600e+07
# Sub-Saharan Africa              1.289883e+06
#
#                             Urban population growth (annual %)  \
# World bank region
# East Asia & Pacific                                   3.425587
# Europe & Central Asia                                 2.351236
# Latin America & Caribbean                             3.003432
# Middle East & North Africa                            5.778795
# North America                                         0.644361
# South Asia                                            6.165372
# Sub-Saharan Africa                                    5.860755
#
#                             Urban population 5 years in the future
# World bank region
# East Asia & Pacific                                   1.076396e+07
# Europe & Central Asia                                 8.915879e+06
# Latin America & Caribbean                             5.549579e+06
# Middle East & North Africa                            4.050156e+06
# North America                                         6.011275e+07
# South Asia                                            2.219639e+07
# Sub-Saharan Africa                                    1.633897e+06

# %%
# Regional averages for the final year in the dataset
avg_by_region_2002 = df[df['year'] == 2002].groupby('World bank region').mean()
avg_by_region_2002
# Out:
#                               year  \
# World bank region
# East Asia & Pacific         2002.0
# Europe & Central Asia       2002.0
# Latin America & Caribbean   2002.0
# Middle East & North Africa  2002.0
# North America               2002.0
# South Asia                  2002.0
# Sub-Saharan Africa          2002.0
#
#                             Adjusted savings: mineral depletion (current US$)  \
# World bank region
# East Asia & Pacific                                              2.282995e+08
# Europe & Central Asia                                            2.510077e+07
# Latin America & Caribbean                                        1.797345e+08
# Middle East & North Africa                                       1.354816e+07
# North America                                                    4.982455e+08
# South Asia                                                       1.358477e+08
# Sub-Saharan Africa                                               2.490374e+07
#
#                             Adjusted savings: energy depletion (current US$)  \
# World bank region
# East Asia & Pacific                                             1.260494e+09
# Europe & Central Asia                                           2.144065e+09
# Latin America & Caribbean                                       1.529591e+09
# Middle East & North Africa                                      6.217336e+09
# North America                                                   1.839586e+10
# South Asia                                                      9.865839e+08
# Sub-Saharan Africa                                              3.896983e+08
#
#                             Population (Total)  Population growth (annual %)  \
# World bank region
# East Asia & Pacific               5.713979e+07                      1.184017
# Europe & Central Asia             1.542280e+07                      0.421066
# Latin America & Caribbean         1.421129e+07                      1.425700
# Middle East & North Africa        1.542516e+07                      2.403944
# North America                     1.063500e+08                      0.825896
# South Asia                        1.786892e+08                      2.049180
# Sub-Saharan Africa                1.458791e+07                      2.537434
#
#                             Population density (people per sq. km of land area)  \
# World bank region
# East Asia & Pacific                                                912.941562
# Europe & Central Asia                                              409.453325
# Latin America & Caribbean                                          143.865287
# Middle East & North Africa                                         199.176435
# North America                                                      431.027461
# South Asia                                                         383.769324
# Sub-Saharan Africa                                                  77.686792
#
#                             Rural population (% of total population)  \
# World bank region
# East Asia & Pacific                                        45.523444
# Europe & Central Asia                                      36.039121
# Latin America & Caribbean                                  38.254753
# Middle East & North Africa                                 27.150981
# North America                                              13.506200
# South Asia                                                 75.647350
# Sub-Saharan Africa                                         64.964196
#
#                             Urban population (% of total)  Rural population  \
# World bank region
# East Asia & Pacific                             54.476556      3.237388e+07
# Europe & Central Asia                           63.960879      4.851956e+06
# Latin America & Caribbean                       61.745247      3.388729e+06
# Middle East & North Africa                      72.849019      6.246905e+06
# North America                                   86.493800      2.153717e+07
# South Asia                                      24.352650      1.287192e+08
# Sub-Saharan Africa                              35.035804      9.805642e+06
#
#                             Urban population  \
# World bank region
# East Asia & Pacific             2.476591e+07
# Europe & Central Asia           1.057084e+07
# Latin America & Caribbean       1.082256e+07
# Middle East & North Africa      9.178257e+06
# North America                   8.481287e+07
# South Asia                      4.996996e+07
# Sub-Saharan Africa              4.782263e+06
#
#                             Urban population growth (annual %)  \
# World bank region
# East Asia & Pacific                                   2.050313
# Europe & Central Asia                                 0.653415
# Latin America & Caribbean                             1.955953
# Middle East & North Africa                            2.835520
# North America                                         1.016630
# South Asia                                            3.887046
# Sub-Saharan Africa                                    3.784896
#
#                             Urban population 5 years in the future
# World bank region
# East Asia & Pacific                                   2.882138e+07
# Europe & Central Asia                                 1.086200e+07
# Latin America & Caribbean                             1.177693e+07
# Middle East & North Africa                            1.048877e+07
# North America                                         9.045350e+07
# South Asia                                            5.704741e+07
# Sub-Saharan Africa                                    5.777149e+06

# %%
# use averages above to calculate each region's percent growth of each feature over our 31-year timespan 
percent_change_region = (avg_by_region_2002 - avg_by_region_1972) / avg_by_region_1972 * 100
percent_change_region
# Out:
#                                 year  \
# World bank region
# East Asia & Pacific         1.521298
# Europe & Central Asia       1.521298
# Latin America & Caribbean   1.521298
# Middle East & North Africa  1.521298
# North America               1.521298
# South Asia                  1.521298
# Sub-Saharan Africa          1.521298
#
#                             Adjusted savings: mineral depletion (current US$)  \
# World bank region
# East Asia & Pacific                                                860.546555
# Europe & Central Asia                                              442.707537
# Latin America & Caribbean                                          595.811007
# Middle East & North Africa                                        1279.508299
# North America                                                        5.586906
# South Asia                                                         999.513177
# Sub-Saharan Africa                                                  72.435071
#
#                             Adjusted savings: energy depletion (current US$)  \
# World bank region
# East Asia & Pacific                                              4310.903900
# Europe & Central Asia                                            7216.383222
# Latin America & Caribbean                                        2473.738953
# Middle East & North Africa                                       1344.627701
# North America                                                     485.196813
# South Asia                                                       3726.983779
# Sub-Saharan Africa                                               2227.589029
#
#                             Population (Total)  Population growth (annual %)  \
# World bank region
# East Asia & Pacific                  53.660838                    -50.616182
# Europe & Central Asia                14.486959                    -66.931753
# Latin America & Caribbean            79.258780                    -29.756572
# Middle East & North Africa          108.642492                    -42.066971
# North America                        37.554900                     28.158870
# South Asia                           90.840533                    -17.098775
# Sub-Saharan Africa                  128.127306                      4.678667
#
#                             Population density (people per sq. km of land area)  \
# World bank region
# East Asia & Pacific                                                 71.227561
# Europe & Central Asia                                               28.806224
# Latin America & Caribbean                                           43.813082
# Middle East & North Africa                                         102.815655
# North America                                                       16.563676
# South Asia                                                         101.491586
# Sub-Saharan Africa                                                  97.341549
#
#                             Rural population (% of total population)  \
# World bank region
# East Asia & Pacific                                       -19.569049
# Europe & Central Asia                                     -18.541098
# Latin America & Caribbean                                 -25.041597
# Middle East & North Africa                                -35.386191
# North America                                             -20.145918
# South Asia                                                -12.177893
# Sub-Saharan Africa                                        -18.639980
#
#                             Urban population (% of total)  Rural population  \
# World bank region
# East Asia & Pacific                             25.520314         16.250166
# Europe & Central Asia                           14.711759         -5.871484
# Latin America & Caribbean                       26.099859          2.959807
# Middle East & North Africa                      25.645950         51.512742
# North America                                    4.101032          6.402134
# South Asia                                      75.666839         70.361049
# Sub-Saharan Africa                              73.856085         92.088570
#
#                             Urban population  \
# World bank region
# East Asia & Pacific               165.239245
# Europe & Central Asia              27.105041
# Latin America & Caribbean         133.421196
# Middle East & North Africa        180.673445
# North America                      48.603360
# South Asia                        176.443714
# Sub-Saharan Africa                270.751676
#
#                             Urban population growth (annual %)  \
# World bank region
# East Asia & Pacific                                 -40.147117
# Europe & Central Asia                               -72.209717
# Latin America & Caribbean                           -34.876072
# Middle East & North Africa                          -50.932329
# North America                                        57.773435
# South Asia                                          -36.953590
# Sub-Saharan Africa                                  -35.419644
#
#                             Urban population 5 years in the future
# World bank region
# East Asia & Pacific                                     167.758211
# Europe & Central Asia                                    21.827626
# Latin America & Caribbean                               112.213080
# Middle East & North Africa                              158.971965
# North America                                            50.473067
# South Asia                                              157.012131
# Sub-Saharan Africa                                      253.581042

# %%
# Averages by income group over our 31-year dataset observations
avg_by_income = df.groupby('World bank, 4 income groups 2017').mean()
avg_by_income
# Out:
#                                          year  \
# World bank, 4 income groups 2017
# High income                       1986.991925
# Low income                        1987.000000
# Lower middle income               1987.073400
# Upper middle income               1987.069354
#
#                                   Adjusted savings: mineral depletion (current US$)  \
# World bank, 4 income groups 2017
# High income                                                            9.752004e+07
# Low income                                                             2.050616e+07
# Lower middle income                                                    4.059258e+07
# Upper middle income                                                    1.030992e+08
#
#                                   Adjusted savings: energy depletion (current US$)  \
# World bank, 4 income groups 2017
# High income                                                           1.999265e+09
# Low income                                                            1.264559e+07
# Lower middle income                                                   6.076786e+08
# Upper middle income                                                   2.108849e+09
#
#                                   Population (Total)  \
# World bank, 4 income groups 2017
# High income                             1.330681e+07
# Low income                              9.925165e+06
# Lower middle income                     3.517837e+07
# Upper middle income                     3.550253e+07
#
#                                   Population growth (annual %)  \
# World bank, 4 income groups 2017
# High income                                           1.437816
# Low income                                            2.551663
# Lower middle income                                   2.297258
# Upper middle income                                   1.530527
#
#                                   Population density (people per sq. km of land area)  \
# World bank, 4 income groups 2017
# High income                                                              662.206600
# Low income                                                                63.464910
# Lower middle income                                                       84.450526
# Upper middle income                                                       96.832389
#
#                                   Rural population (% of total population)  \
# World bank, 4 income groups 2017
# High income                                                      29.307318
# Low income                                                       77.229266
# Lower middle income                                              64.396218
# Upper middle income                                              48.936307
#
#                                   Urban population (% of total)  \
# World bank, 4 income groups 2017
# High income                                           70.692682
# Low income                                            22.770734
# Lower middle income                                   35.603782
# Upper middle income                                   51.063693
#
#                                   Rural population  Urban population  \
# World bank, 4 income groups 2017
# High income                           3.489338e+06      9.817475e+06
# Low income                            7.769303e+06      2.155862e+06
# Lower middle income                   2.475782e+07      1.042056e+07
# Upper middle income                   2.051394e+07      1.498859e+07
#
#                                   Urban population growth (annual %)  \
# World bank, 4 income groups 2017
# High income                                                 1.892677
# Low income                                                  4.749218
# Lower middle income                                         3.705377
# Upper middle income                                         2.640003
#
#                                   Urban population 5 years in the future
# World bank, 4 income groups 2017
# High income                                                 1.036966e+07
# Low income                                                  2.616117e+06
# Lower middle income                                         1.220157e+07
# Upper middle income                                         1.730703e+07

# %% [markdown]
# From finding the averages of each income group over our 31-year span above, we notice several things. The average population is highest in "upper middle income" countries, followed by "lower middle income", "high income", and "low income" countries at the very bottom. Income and population growth (as a percentage) are inversely related with high income countries having the least growth and low income countries having the most. Population density is directly related to income, with high income countries being the most densely populated. Urban population percentage numbers have a similar correlation, with the rural population percentage being inversely related to income. Lower income countries have the highest urban population growth (as a percentage) while the already densely-populated higher income countries exhibit less urban growth.

# %%
# Income group averages for the first year in the dataset
avg_by_income_1972 = df[df['year'] == 1972].groupby('World bank, 4 income groups 2017').mean()
avg_by_income_1972
# Out:
#                                     year  \
# World bank, 4 income groups 2017
# High income                       1972.0
# Low income                        1972.0
# Lower middle income               1972.0
# Upper middle income               1972.0
#
#                                   Adjusted savings: mineral depletion (current US$)  \
# World bank, 4 income groups 2017
# High income                                                            3.465747e+07
# Low income                                                             1.079119e+07
# Lower middle income                                                    1.155035e+07
# Upper middle income                                                    1.666711e+07
#
#                                   Adjusted savings: energy depletion (current US$)  \
# World bank, 4 income groups 2017
# High income                                                           2.162264e+08
# Low income                                                            7.434861e+05
# Lower middle income                                                   2.944195e+07
# Upper middle income                                                   1.269264e+08
#
#                                   Population (Total)  \
# World bank, 4 income groups 2017
# High income                             1.178996e+07
# Low income                              6.620555e+06
# Lower middle income                     2.473574e+07
# Upper middle income                     2.779688e+07
#
#                                   Population growth (annual %)  \
# World bank, 4 income groups 2017
# High income                                           1.973140
# Low income                                            2.384223
# Lower middle income                                   2.692289
# Upper middle income                                   1.874822
#
#                                   Population density (people per sq. km of land area)  \
# World bank, 4 income groups 2017
# High income                                                              532.963769
# Low income                                                                42.652421
# Lower middle income                                                       59.207070
# Upper middle income                                                       78.718869
#
#                                   Rural population (% of total population)  \
# World bank, 4 income groups 2017
# High income                                                      34.797439
# Low income                                                       83.310871
# Lower middle income                                              71.338961
# Upper middle income                                              57.348344
#
#                                   Urban population (% of total)  \
# World bank, 4 income groups 2017
# High income                                           65.202561
# Low income                                            16.689129
# Lower middle income                                   28.661039
# Upper middle income                                   42.651656
#
#                                   Rural population  Urban population  \
# World bank, 4 income groups 2017
# High income                           3.574704e+06      8.215256e+06
# Low income                            5.512750e+06      1.107805e+06
# Lower middle income                   1.891741e+07      5.818327e+06
# Upper middle income                   1.871708e+07      9.079796e+06
#
#                                   Urban population growth (annual %)  \
# World bank, 4 income groups 2017
# High income                                                 2.943833
# Low income                                                  5.627280
# Lower middle income                                         4.528595
# Upper middle income                                         3.658477
#
#                                   Urban population 5 years in the future
# World bank, 4 income groups 2017
# High income                                                 8.780447e+06
# Low income                                                  1.375458e+06
# Lower middle income                                         7.061301e+06
# Upper middle income                                         1.057670e+07

# %%
# Income group averages for the final year in the dataset
avg_by_income_2002 = df[df['year'] == 2002].groupby('World bank, 4 income groups 2017').mean()
avg_by_income_2002
# Out:
#                                     year  \
# World bank, 4 income groups 2017
# High income                       2002.0
# Low income                        2002.0
# Lower middle income               2002.0
# Upper middle income               2002.0
#
#                                   Adjusted savings: mineral depletion (current US$)  \
# World bank, 4 income groups 2017
# High income                                                            1.120868e+08
# Low income                                                             9.309332e+06
# Lower middle income                                                    7.293042e+07
# Upper middle income                                                    1.520822e+08
#
#                                   Adjusted savings: energy depletion (current US$)  \
# World bank, 4 income groups 2017
# High income                                                           2.585977e+09
# Low income                                                            4.874037e+06
# Lower middle income                                                   1.035822e+09
# Upper middle income                                                   3.558464e+09
#
#                                   Population (Total)  \
# World bank, 4 income groups 2017
# High income                             1.474806e+07
# Low income                              1.438796e+07
# Lower middle income                     4.618756e+07
# Upper middle income                     4.225108e+07
#
#                                   Population growth (annual %)  \
# World bank, 4 income groups 2017
# High income                                           1.183136
# Low income                                            2.739996
# Lower middle income                                   1.663323
# Upper middle income                                   0.998422
#
#                                   Population density (people per sq. km of land area)  \
# World bank, 4 income groups 2017
# High income                                                              813.479015
# Low income                                                                89.724692
# Lower middle income                                                      113.161926
# Upper middle income                                                      114.558123
#
#                                   Rural population (% of total population)  \
# World bank, 4 income groups 2017
# High income                                                      25.836592
# Low income                                                       71.566277
# Lower middle income                                              58.424562
# Upper middle income                                              42.327244
#
#                                   Urban population (% of total)  \
# World bank, 4 income groups 2017
# High income                                           74.163408
# Low income                                            28.433723
# Lower middle income                                   41.575438
# Upper middle income                                   57.672756
#
#                                   Rural population  Urban population  \
# World bank, 4 income groups 2017
# High income                           3.302989e+06      1.144507e+07
# Low income                            1.076186e+07      3.626105e+06
# Lower middle income                   3.039679e+07      1.579078e+07
# Upper middle income                   2.018357e+07      2.206750e+07
#
#                                   Urban population growth (annual %)  \
# World bank, 4 income groups 2017
# High income                                                 1.465171
# Low income                                                  4.206807
# Lower middle income                                         2.617969
# Upper middle income                                         1.601057
#
#                                   Urban population 5 years in the future
# World bank, 4 income groups 2017
# High income                                                 1.215973e+07
# Low income                                                  4.381140e+06
# Lower middle income                                         1.803753e+07
# Upper middle income                                         2.489827e+07

# %%
# use averages above to calculate percent growth of each feature over our 31-year timespan with countries
# grouped by income level
percent_change_income = (avg_by_income_2002 - avg_by_income_1972) / avg_by_income_1972 * 100
percent_change_income
# Out:
#                                       year  \
# World bank, 4 income groups 2017
# High income                       1.521298
# Low income                        1.521298
# Lower middle income               1.521298
# Upper middle income               1.521298
#
#                                   Adjusted savings: mineral depletion (current US$)  \
# World bank, 4 income groups 2017
# High income                                                              223.413155
# Low income                                                               -13.732070
# Lower middle income                                                      531.413282
# Upper middle income                                                      812.469038
#
#                                   Adjusted savings: energy depletion (current US$)  \
# World bank, 4 income groups 2017
# High income                                                            1095.958043
# Low income                                                              555.565317
# Lower middle income                                                    3418.182392
# Upper middle income                                                    2703.565701
#
#                                   Population (Total)  \
# World bank, 4 income groups 2017
# High income                                25.090020
# Low income                                117.322623
# Lower middle income                        86.724026
# Upper middle income                        51.999376
#
#                                   Population growth (annual %)  \
# World bank, 4 income groups 2017
# High income                                         -40.037920
# Low income                                           14.921979
# Lower middle income                                 -38.218999
# Upper middle income                                 -46.745757
#
#                                   Population density (people per sq. km of land area)  \
# World bank, 4 income groups 2017
# High income                                                               52.633080
# Low income                                                               110.362483
# Lower middle income                                                       91.129077
# Upper middle income                                                       45.528161
#
#                                   Rural population (% of total population)  \
# World bank, 4 income groups 2017
# High income                                                     -25.751456
# Low income                                                      -14.097312
# Lower middle income                                             -18.102870
# Upper middle income                                             -26.192737
#
#                                   Urban population (% of total)  \
# World bank, 4 income groups 2017
# High income                                           13.743091
# Low income                                            70.372717
# Lower middle income                                   45.059075
# Upper middle income                                   35.218096
#
#                                   Rural population  Urban population  \
# World bank, 4 income groups 2017
# High income                              -7.601055         39.314885
# Low income                               95.217601        227.323484
# Lower middle income                      60.681550        171.397189
# Upper middle income                       7.835055        143.039655
#
#                                   Urban population growth (annual %)  \
# World bank, 4 income groups 2017
# High income                                               -50.229123
# Low income                                                -25.242619
# Lower middle income                                       -42.190252
# Upper middle income                                       -56.237049
#
#                                   Urban population 5 years in the future
# World bank, 4 income groups 2017
# High income                                                    38.486461
# Low income                                                    218.522292
# Lower middle income                                           155.441999
# Upper middle income                                           135.406891

# %%
df.median()
# Out:
# year                                                   1.987000e+03
# Adjusted savings: mineral depletion (current US$)      0.000000e+00
# Adjusted savings: energy depletion (current US$)       0.000000e+00
# Population (Total)                                     4.359166e+06
# Population growth (annual %)                           1.842203e+00
# Population density (people per sq. km of land area)    5.659393e+01
# Rural population (% of total population)               5.094880e+01
# Urban population (% of total)                          4.905120e+01
# Rural population                                       2.100014e+06
# Urban population                                       1.693451e+06
# Urban population growth (annual %)                     2.710241e+00
# Urban population 5 years in the future                 1.975930e+06
# dtype: float64

# %%
med_by_region = df.groupby('World bank region').median()
med_by_region
# Out:
#                               year  \
# World bank region
# East Asia & Pacific         1987.0
# Europe & Central Asia       1987.0
# Latin America & Caribbean   1987.0
# Middle East & North Africa  1987.0
# North America               1987.0
# South Asia                  1987.0
# Sub-Saharan Africa          1987.0
#
#                             Adjusted savings: mineral depletion (current US$)  \
# World bank region
# East Asia & Pacific                                              0.000000e+00
# Europe & Central Asia                                            0.000000e+00
# Latin America & Caribbean                                        0.000000e+00
# Middle East & North Africa                                       0.000000e+00
# North America                                                    8.665239e+08
# South Asia                                                       0.000000e+00
# Sub-Saharan Africa                                               0.000000e+00
#
#                             Adjusted savings: energy depletion (current US$)  \
# World bank region
# East Asia & Pacific                                             0.000000e+00
# Europe & Central Asia                                           1.004977e+06
# Latin America & Caribbean                                       0.000000e+00
# Middle East & North Africa                                      1.157528e+09
# North America                                                   6.773710e+09
# South Asia                                                      6.164621e+05
# Sub-Saharan Africa                                              0.000000e+00
#
#                             Population (Total)  Population growth (annual %)  \
# World bank region
# East Asia & Pacific                  1128016.5                      1.891734
# Europe & Central Asia                4815116.5                      0.599128
# Latin America & Caribbean            2890648.5                      1.732548
# Middle East & North Africa           4279405.5                      2.851974
# North America                       26550000.0                      0.954477
# South Asia                          17616036.5                      2.313502
# Sub-Saharan Africa                   5417980.0                      2.712966
#
#                             Population density (people per sq. km of land area)  \
# World bank region
# East Asia & Pacific                                                 83.838068
# Europe & Central Asia                                               85.493642
# Latin America & Caribbean                                           50.687225
# Middle East & North Africa                                          39.805531
# North America                                                       26.453768
# South Asia                                                         194.765391
# Sub-Saharan Africa                                                  28.179334
#
#                             Rural population (% of total population)  \
# World bank region
# East Asia & Pacific                                          53.1070
# Europe & Central Asia                                        37.3652
# Latin America & Caribbean                                    47.2548
# Middle East & North Africa                                   30.6352
# North America                                                22.5436
# South Asia                                                   80.7581
# Sub-Saharan Africa                                           72.2156
#
#                             Urban population (% of total)  Rural population  \
# World bank region
# East Asia & Pacific                               46.8930          416049.5
# Europe & Central Asia                             62.6348         2076963.5
# Latin America & Caribbean                         52.7452         1132337.5
# Middle East & North Africa                        69.3648          927815.5
# North America                                     77.4564         6253799.0
# South Asia                                        19.2419        15053011.5
# Sub-Saharan Africa                                27.7844         4235438.0
#
#                             Urban population  \
# World bank region
# East Asia & Pacific                 379891.5
# Europe & Central Asia              2817835.5
# Latin America & Caribbean          1331475.0
# Middle East & North Africa         2785179.0
# North America                     20296201.0
# South Asia                         2856107.0
# Sub-Saharan Africa                 1053451.0
#
#                             Urban population growth (annual %)  \
# World bank region
# East Asia & Pacific                                   2.840459
# Europe & Central Asia                                 1.076216
# Latin America & Caribbean                             2.527302
# Middle East & North Africa                            3.791706
# North America                                         1.110611
# South Asia                                            4.122767
# Sub-Saharan Africa                                    4.448955
#
#                             Urban population 5 years in the future
# World bank region
# East Asia & Pacific                                       424279.5
# Europe & Central Asia                                    2965894.0
# Latin America & Caribbean                                1611123.5
# Middle East & North Africa                               3424101.5
# North America                                           21965565.0
# South Asia                                               2969993.5
# Sub-Saharan Africa                                       1340160.0

# %%
med_by_income = df.groupby('World bank, 4 income groups 2017').median()
med_by_income
# Out:
#                                     year  \
# World bank, 4 income groups 2017
# High income                       1987.0
# Low income                        1987.0
# Lower middle income               1987.0
# Upper middle income               1987.0
#
#                                   Adjusted savings: mineral depletion (current US$)  \
# World bank, 4 income groups 2017
# High income                                                                0.000000
# Low income                                                                 0.000000
# Lower middle income                                                        0.000000
# Upper middle income                                                     3053.244684
#
#                                   Adjusted savings: energy depletion (current US$)  \
# World bank, 4 income groups 2017
# High income                                                                0.00000
# Low income                                                                 0.00000
# Lower middle income                                                     3862.19346
# Upper middle income                                                        0.00000
#
#                                   Population (Total)  \
# World bank, 4 income groups 2017
# High income                                1996351.0
# Low income                                 6470628.0
# Lower middle income                        5849980.0
# Upper middle income                        3566605.0
#
#                                   Population growth (annual %)  \
# World bank, 4 income groups 2017
# High income                                           0.921360
# Low income                                            2.655961
# Lower middle income                                   2.426006
# Upper middle income                                   1.576877
#
#                                   Population density (people per sq. km of land area)  \
# World bank, 4 income groups 2017
# High income                                                              111.786112
# Low income                                                                31.489539
# Lower middle income                                                       48.259567
# Upper middle income                                                       50.002075
#
#                                   Rural population (% of total population)  \
# World bank, 4 income groups 2017
# High income                                                        26.3470
# Low income                                                         78.5404
# Lower middle income                                                64.5829
# Upper middle income                                                48.6140
#
#                                   Urban population (% of total)  \
# World bank, 4 income groups 2017
# High income                                             73.6530
# Low income                                              21.4596
# Lower middle income                                     35.4171
# Upper middle income                                     51.3860
#
#                                   Rural population  Urban population  \
# World bank, 4 income groups 2017
# High income                               424683.0         1554728.0
# Low income                               5209206.0         1272425.0
# Lower middle income                      3412564.5         2258392.0
# Upper middle income                      1831012.0         1849315.0
#
#                                   Urban population growth (annual %)  \
# World bank, 4 income groups 2017
# High income                                                 1.340456
# Low income                                                  4.508463
# Lower middle income                                         3.705363
# Upper middle income                                         2.530375
#
#                                   Urban population 5 years in the future
# World bank, 4 income groups 2017
# High income                                                    1605474.0
# Low income                                                     1569852.0
# Lower middle income                                            2570119.5
# Upper middle income                                            2146159.0

# %%
# Find quantiles from 
df.quantile([0.025, 0.975])
# Out:
#          year  Adjusted savings: mineral depletion (current US$)  \
# 0.025  1972.0                                       0.000000e+00
# 0.975  2002.0                                       9.073318e+08
#
#        Adjusted savings: energy depletion (current US$)  Population (Total)  \
# 0.025                                      0.000000e+00             25502.5
# 0.975                                      1.348437e+10         138234688.0
#
#        Population growth (annual %)  \
# 0.025                     -0.793132
# 0.975                      5.165273
#
#        Population density (people per sq. km of land area)  \
# 0.025                                           1.907862
# 0.975                                        1084.347656
#
#        Rural population (% of total population)  \
# 0.025                                   1.78485
# 0.975                                  90.54150
#
#        Urban population (% of total)  Rural population  Urban population  \
# 0.025                        9.45850           2252.75          14102.75
# 0.975                       98.21515       61164085.25       89929277.00
#
#        Urban population growth (annual %)  \
# 0.025                           -0.812936
# 0.975                            8.408388
#
#        Urban population 5 years in the future
# 0.025                                 15296.5
# 0.975                              96787145.5

# %% [markdown]
# ## Other Stats

# %%
# We can find the variance of each feature over the 31-year span by using
df.var(ddof=0)
# 0 degrees of freedom because we are assuming we know the stats of the entire population of observations during the
# time period 2971-2002. Realisticaly, we have 210 of the 214 countries from the original dataset, and we are missing
# a few years from 3 different countries. However, since we have the overwhelming majority of possible observations in
# this dataset, we will assume that it is an accurate representation.
# Out:
# year                                                   8.007924e+01
# Adjusted savings: mineral depletion (current US$)      1.014316e+17
# Adjusted savings: energy depletion (current US$)       3.528346e+19
# Population (Total)                                     9.639577e+15
# Population growth (annual %)                           2.638248e+00
# Population density (people per sq. km of land area)    1.878239e+06
# Rural population (% of total population)               6.183887e+02
# Urban population (% of total)                          6.183887e+02
# Rural population                                       5.004639e+15
# Urban population                                       1.004397e+15
# Urban population growth (annual %)                     6.470303e+00
# Urban population 5 years in the future                 1.346603e+15
# dtype: float64

# %%
# Variance by income group
df.groupby('World bank, 4 income groups 2017').var(ddof=0)
# Out:
#                                        year  \
# World bank, 4 income groups 2017
# High income                       80.058257
# Low income                        80.000000
# Lower middle income               80.116946
# Upper middle income               80.110780
#
#                                   Adjusted savings: mineral depletion (current US$)  \
# World bank, 4 income groups 2017
# High income                                                            1.788754e+17
# Low income                                                             4.109070e+15
# Lower middle income                                                    1.863233e+16
# Upper middle income                                                    1.285196e+17
#
#                                   Adjusted savings: energy depletion (current US$)  \
# World bank, 4 income groups 2017
# High income                                                           6.968846e+19
# Low income                                                            3.416930e+15
# Lower middle income                                                   3.117358e+18
# Upper middle income                                                   3.764879e+19
#
#                                   Population (Total)  \
# World bank, 4 income groups 2017
# High income                             1.191952e+15
# Low income                              1.074099e+14
# Lower middle income                     1.380130e+16
# Upper middle income                     2.178466e+16
#
#                                   Population growth (annual %)  \
# World bank, 4 income groups 2017
# High income                                           3.640346
# Low income                                            2.201491
# Lower middle income                                   1.569748
# Upper middle income                                   1.777035
#
#                                   Population density (people per sq. km of land area)  \
# World bank, 4 income groups 2017
# High income                                                            5.207422e+06
# Low income                                                             5.560134e+03
# Lower middle income                                                    1.557590e+04
# Upper middle income                                                    1.684765e+04
#
#                                   Rural population (% of total population)  \
# World bank, 4 income groups 2017
# High income                                                     413.258660
# Low income                                                      143.600888
# Lower middle income                                             275.594301
# Upper middle income                                             298.844077
#
#                                   Urban population (% of total)  \
# World bank, 4 income groups 2017
# High income                                          413.258660
# Low income                                           143.600888
# Lower middle income                                  275.594301
# Upper middle income                                  298.844077
#
#                                   Rural population  Urban population  \
# World bank, 4 income groups 2017
# High income                           7.401129e+13      6.810993e+14
# Low income                            7.220574e+13      7.158643e+12
# Lower middle income                   7.634752e+15      9.432242e+14
# Upper middle income                   1.152431e+16      1.997414e+15
#
#                                   Urban population growth (annual %)  \
# World bank, 4 income groups 2017
# High income                                                 4.928700
# Low income                                                  5.056661
# Lower middle income                                         7.614493
# Upper middle income                                         4.275222
#
#                                   Urban population 5 years in the future
# World bank, 4 income groups 2017
# High income                                                 7.662305e+14
# Low income                                                  9.348049e+12
# Lower middle income                                         1.261906e+15
# Upper middle income                                         2.874404e+15

# %%
# Variance by region
df.groupby('World bank region').var(ddof=0)
# Out:
#                                  year  \
# World bank region
# East Asia & Pacific         80.000000
# Europe & Central Asia       80.108866
# Latin America & Caribbean   80.000000
# Middle East & North Africa  80.491179
# North America               80.000000
# South Asia                  80.000000
# Sub-Saharan Africa          80.000000
#
#                             Adjusted savings: mineral depletion (current US$)  \
# World bank region
# East Asia & Pacific                                              1.926965e+17
# Europe & Central Asia                                            4.508806e+15
# Latin America & Caribbean                                        1.662593e+17
# Middle East & North Africa                                       1.772752e+15
# North America                                                    7.429225e+17
# South Asia                                                       3.190158e+16
# Sub-Saharan Africa                                               5.514556e+16
#
#                             Adjusted savings: energy depletion (current US$)  \
# World bank region
# East Asia & Pacific                                             8.067918e+18
# Europe & Central Asia                                           2.905701e+19
# Latin America & Caribbean                                       8.172346e+18
# Middle East & North Africa                                      7.184844e+19
# North America                                                   7.875546e+20
# South Asia                                                      1.796341e+18
# Sub-Saharan Africa                                              1.436630e+18
#
#                             Population (Total)  Population growth (annual %)  \
# World bank region
# East Asia & Pacific               3.246078e+16                      1.902447
# Europe & Central Asia             6.338850e+14                      1.055557
# Latin America & Caribbean         6.873945e+14                      1.754278
# Middle East & North Africa        2.419316e+14                      5.341807
# North America                     1.226194e+16                      0.263359
# South Asia                        7.182553e+16                      2.187243
# Sub-Saharan Africa                2.488834e+14                      1.711192
#
#                             Population density (people per sq. km of land area)  \
# World bank region
# East Asia & Pacific                                              4.904397e+06
# Europe & Central Asia                                            3.627124e+06
# Latin America & Caribbean                                        1.901699e+04
# Middle East & North Africa                                       7.043054e+04
# North America                                                    2.869237e+05
# South Asia                                                       7.924397e+04
# Sub-Saharan Africa                                               7.710439e+03
#
#                             Rural population (% of total population)  \
# World bank region
# East Asia & Pacific                                       802.583574
# Europe & Central Asia                                     321.744167
# Latin America & Caribbean                                 429.955502
# Middle East & North Africa                                397.216764
# North America                                             127.939527
# South Asia                                                 50.813907
# Sub-Saharan Africa                                        188.499589
#
#                             Urban population (% of total)  Rural population  \
# World bank region
# East Asia & Pacific                            802.583574      1.742264e+16
# Europe & Central Asia                          321.744167      5.826798e+13
# Latin America & Caribbean                      429.955502      5.283646e+13
# Middle East & North Africa                     397.216764      6.441651e+13
# North America                                  127.939527      7.156604e+14
# South Asia                                      50.813907      3.975728e+16
# Sub-Saharan Africa                             188.499589      1.184913e+14
#
#                             Urban population  \
# World bank region
# East Asia & Pacific             2.680984e+15
# Europe & Central Asia           3.219532e+14
# Latin America & Caribbean       3.751165e+14
# Middle East & North Africa      6.455232e+13
# North America                   7.089262e+15
# South Asia                      4.774685e+15
# Sub-Saharan Africa              3.093019e+13
#
#                             Urban population growth (annual %)  \
# World bank region
# East Asia & Pacific                                   7.622916
# Europe & Central Asia                                 1.891151
# Latin America & Caribbean                             3.015315
# Middle East & North Africa                            6.787156
# North America                                         0.347943
# South Asia                                            7.447319
# Sub-Saharan Africa                                    5.434407
#
#                             Urban population 5 years in the future
# World bank region
# East Asia & Pacific                                   3.944004e+15
# Europe & Central Asia                                 3.399092e+14
# Latin America & Caribbean                             4.789245e+14
# Middle East & North Africa                            8.437236e+13
# North America                                         8.148728e+15
# South Asia                                            6.321958e+15
# Sub-Saharan Africa                                    4.613507e+13

# %% [markdown]
# ### Computing the Empirical Cumulative Distribution Function

# %%
def ecdf(data):
    """Compute ECDF for a one-dimensional array of measurements."""
    # Number of data points: n
    n = len(data)

    # x-data for the ECDF: x
    x = np.sort(data)

    # y-data for the ECDF: y
    y = np.arange(1, n+1) / n

    return x, y

# %%
# ECDF of Total Population for first and last year in dataset
x_std_start, y_std_start = ecdf(df['Population (Total)'][df['year'] == 1972])
x_std_end, y_std_end = ecdf(df['Population (Total)'][df['year'] == 2002])

_ = plt.plot(x_std_start, y_std_start, marker = '.', linestyle='none', label='1972')
_ = plt.plot(x_std_end, y_std_end, marker = '.', linestyle='none', label='2002')
_ = plt.legend(loc='lower right')
_ = plt.xlabel('Population (Total)')
_ = plt.title('ECDF of Total Population for 1972 and 2002')
plt.show()

# %%
# ECDF of Urban Population for first and last year in dataset
x_std_start, y_std_start = ecdf(df['Urban population'][df['year'] == 1972])
x_std_end, y_std_end = ecdf(df['Urban population'][df['year'] == 2002])

_ = plt.plot(x_std_start, y_std_start, marker = '.', linestyle='none', label='1972')
_ = plt.plot(x_std_end, y_std_end, marker = '.', linestyle='none', label='2002')
_ = plt.legend(loc='lower right')
_ = plt.xlabel('Urban Population')
_ = plt.title('ECDF of Urban Population for 1972 and 2002')
plt.show()

# %%
def plotyear(year):
    data = df[df.year == year]
    area = 200 * data['Urban population growth (annual %)'] # Change proportions
    colors = data['World bank region'].map({'South Asia': '#377eb8', 'Europe & Central Asia': '#ff7f00',
                                           'Middle East & North Africa': '#4daf4a', 'East Asia & Pacific': '#f781bf',
                                           'Sub-Saharan Africa': '#a65628', 'Latin America & Caribbean': '#984ea3',
                                           'North America': '#999999'})

    data.plot.scatter('Population (Total)','Urban population', linewidths=1,
                     edgecolors='k', figsize=(12,9), c=colors, s=area, alpha=0.8)
    
    plt.xlabel('Total Population')
    plt.ylabel('Urban Population')
    plt.title('Total Population vs. Urban Population')

# %%
plotyear(2002)
# Out:
# /usr/local/lib/python3.8/site-packages/matplotlib/collections.py:922: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
# The code below creates an interactive plot that allows us to move the slider to change the year
interact(plotyear, year=widgets.IntSlider(min=1972, max=2002, 
                                           step=1, value=1972))
# Out:
# interactive(children=(IntSlider(value=1972, description='year', max=2002, min=1972), Output()), _dom_classes=(…
# <function __main__.plotyear(year)>

# %% [markdown]
# # Data by region

# %%
# We create a list of the unique entries in "World bank region"
wb_regions = df['World bank region'].unique().tolist()
wb_regions
# Out:
# ['South Asia',
#  'Europe & Central Asia',
#  'Middle East & North Africa',
#  'East Asia & Pacific',
#  'Sub-Saharan Africa',
#  'Latin America & Caribbean',
#  'North America']

# %%
# We can see how many countries are in each region
countries_per_region = dict(df.groupby('World bank region')['country'].nunique())
countries_per_region
# Out:
# {'East Asia & Pacific': 36,
#  'Europe & Central Asia': 56,
#  'Latin America & Caribbean': 38,
#  'Middle East & North Africa': 21,
#  'North America': 3,
#  'South Asia': 8,
#  'Sub-Saharan Africa': 48}

# %%
# We can also plot a bar graph to see how the regions stack up
region_keys = list(countries_per_region.keys())
region_values = list(countries_per_region.values())

_ = plt.figure(figsize=(12,8))
_ = sns.barplot(region_keys, region_values, order=['Europe & Central Asia', 'East Asia & Pacific', 
                                                  'South Asia', 'Middle East & North Africa', 'Sub-Saharan Africa',
                                                  'Latin America & Caribbean', 'North America'])
_ = plt.xticks(rotation=30)
_ = plt.xlabel('Region')
_ = plt.ylabel('Country Count')
_ = plt.title('Number of Countries per Region')
plt.tight_layout()
plt.show()

# %%
# Total population by region
regional_pop_tot_2002 = dict(df['Population (Total)'][df.year == 2002].groupby(df['World bank region']).sum())
regional_pop_tot_2002
# Out:
# {'East Asia & Pacific': 2057032608.0,
#  'Europe & Central Asia': 863676818.0,
#  'Latin America & Caribbean': 540028983.0,
#  'Middle East & North Africa': 323928401.0,
#  'North America': 319050105.0,
#  'South Asia': 1429513552.0,
#  'Sub-Saharan Africa': 700219447.0}

# %%
for key in regional_pop_tot_2002: 
    print("{:.0f}%".format(regional_pop_tot_2002[key]/world_pop_tot_2002*100, 2), 
          "of the world's population was located in the", str(key), "region in 2002")
# Out:
# 33% of the world's population was located in the East Asia & Pacific region in 2002
# 14% of the world's population was located in the Europe & Central Asia region in 2002
# 9% of the world's population was located in the Latin America & Caribbean region in 2002
# 5% of the world's population was located in the Middle East & North Africa region in 2002
# 5% of the world's population was located in the North America region in 2002
# 23% of the world's population was located in the South Asia region in 2002
# 11% of the world's population was located in the Sub-Saharan Africa region in 2002

# %%
# bar chart based on sum of pop feature instead of country count
_ = plt.figure(figsize=(11,8))
_ = sns.barplot(list(regional_pop_tot_2002.keys()), list(regional_pop_tot_2002.values()), 
                order=['Europe & Central Asia', 'East Asia & Pacific', 'South Asia', 'Middle East & North Africa', 
                       'Sub-Saharan Africa', 'Latin America & Caribbean', 'North America'])
_ = plt.xticks(rotation=30)
_ = plt.xlabel('Region')
_ = plt.ylabel('Population')
_ = plt.title('Population per Region')
plt.savefig('Population per Region.png')
plt.tight_layout()
plt.show()

# %%
_ = plt.figure(figsize=(10,8))
_ = sns.distplot(urban_pop_perc_2002['Urban population']
                 .loc[urban_pop_perc_2002['World bank region'] == 'East Asia & Pacific'], bins=50,
                 label='East Asia & Pacific')
_ = sns.distplot(urban_pop_perc_2002['Urban population']
                 .loc[urban_pop_perc_2002['World bank region'] == 'South Asia'], bins=50, label='South Asia')
_ = sns.distplot(urban_pop_perc_2002['Urban population']
                 .loc[urban_pop_perc_2002['World bank region'] == 'Middle East & North Africa'], bins=50, 
                 label ='Middle East & North Africa')
_ = sns.distplot(urban_pop_perc_2002['Urban population']
                 .loc[urban_pop_perc_2002['World bank region'] == 'Sub-Saharan Africa'], bins=50, 
                 label ='Sub-Saharan Africa')
_ = sns.distplot(urban_pop_perc_2002['Urban population']
                 .loc[urban_pop_perc_2002['World bank region'] == 'Latin America & Caribbean'], bins=50, 
                 label ='Latin America & Caribbean')
_ = sns.distplot(urban_pop_perc_2002['Urban population']
                 .loc[urban_pop_perc_2002['World bank region'] == 'Europe & Central Asia'], bins=50, 
                 label ='Europe & Central Asia')
_ = sns.distplot(urban_pop_perc_2002['Urban population']
                 .loc[urban_pop_perc_2002['World bank region'] == 'North America'], bins=50, label ='North America')

_ = plt.title('Urban Population Distribution by Region')
plt.legend()
plt.show()

# %%
_ = plt.figure(figsize=(10,8))
_ = sns.distplot(urban_pop_perc_2002['Urban population']
                 .loc[(urban_pop_perc_2002['World bank region'] == 'East Asia & Pacific')
                     & (urban_pop_perc_2002['Urban population'] < 4e7)], bins=50,
                 label='East Asia & Pacific')
_ = sns.distplot(urban_pop_perc_2002['Urban population']
                 .loc[(urban_pop_perc_2002['World bank region'] == 'South Asia')
                     & (urban_pop_perc_2002['Urban population'] < 4e7)], bins=50, label='South Asia')
_ = sns.distplot(urban_pop_perc_2002['Urban population']
                 .loc[(urban_pop_perc_2002['World bank region'] == 'Middle East & North Africa')
                     & (urban_pop_perc_2002['Urban population'] < 4e7)], bins=50, 
                 label ='Middle East & North Africa')
_ = sns.distplot(urban_pop_perc_2002['Urban population']
                 .loc[(urban_pop_perc_2002['World bank region'] == 'Sub-Saharan Africa')
                     & (urban_pop_perc_2002['Urban population'] < 4e7)], bins=50, 
                 label ='Sub-Saharan Africa')
_ = sns.distplot(urban_pop_perc_2002['Urban population']
                 .loc[(urban_pop_perc_2002['World bank region'] == 'Latin America & Caribbean')
                     & (urban_pop_perc_2002['Urban population'] < 4e7)], bins=50, 
                 label ='Latin America & Caribbean')
_ = sns.distplot(urban_pop_perc_2002['Urban population']
                 .loc[(urban_pop_perc_2002['World bank region'] == 'Europe & Central Asia')
                     & (urban_pop_perc_2002['Urban population'] < 4e7)], bins=50, 
                 label ='Europe & Central Asia')
_ = sns.distplot(urban_pop_perc_2002['Urban population']
                 .loc[(urban_pop_perc_2002['World bank region'] == 'North America')
                     & (urban_pop_perc_2002['Urban population'] < 4e7)], bins=50, label ='North America')
_ = plt.title('Urban Population Distribution by Region (Only < 4e7 Shown)')
plt.legend()
plt.show()

# %%
_ = plt.figure(figsize=(10,8))
_ = sns.distplot(urban_pop_perc_2002['Urban population']
                 .loc[urban_pop_perc_2002['World bank region'] == 'East Asia & Pacific'], bins=20)
_ = plt.title('East Asia & Pacific Urban Population Distribution')
plt.show()

# %%
_ = plt.figure(figsize=(10,8))
_ = sns.distplot(urban_pop_perc_2002['Urban population']
                 .loc[urban_pop_perc_2002['World bank region'] == 'South Asia'], bins=20, color='orange')
_ = plt.title('South Asia Urban Population Distribution')
plt.show()

# %%
_ = plt.figure(figsize=(10,8))
_ = sns.distplot(urban_pop_perc_2002['Urban population']
                 .loc[urban_pop_perc_2002['World bank region'] == 'Middle East & North Africa'], bins=20, color='green')
_ = plt.title('Middle East & North Africa Urban Population Distribution')

plt.show()

# %%
_ = plt.figure(figsize=(10,8))
_ = sns.distplot(urban_pop_perc_2002['Urban population']
                 .loc[urban_pop_perc_2002['World bank region'] == 'Sub-Saharan Africa'], bins=20, color='red')
_ = plt.title('Sub-Saharan Africa Urban Population Distribution')
plt.show()

# %%
_ = plt.figure(figsize=(10,8))
_ = sns.distplot(urban_pop_perc_2002['Urban population']
                 .loc[urban_pop_perc_2002['World bank region'] == 'Latin America & Caribbean'], bins=20, color='purple')
_ = plt.title('Latin America & Caribbean Urban Population Distribution')
plt.show()

# %%
_ = plt.figure(figsize=(10,8))
_ = sns.distplot(urban_pop_perc_2002['Urban population']
                 .loc[urban_pop_perc_2002['World bank region'] == 'Europe & Central Asia'], bins=20, color='brown')
_ = plt.title('Europe & Central Asia Urban Population Distribution')
plt.show()

# %%
_ = plt.figure(figsize=(10,8))
_ = sns.distplot(urban_pop_perc_2002['Urban population']
                 .loc[urban_pop_perc_2002['World bank region'] == 'North America'], bins=20, color='pink')
_ = plt.title('North America Urban Population Distribution')
plt.show()

# %%
region_year = df.groupby(['World bank region', 'year'], as_index=False).mean()
region_year
# Out:
#        World bank region  year  \
# 0    East Asia & Pacific  1972
# 1    East Asia & Pacific  1973
# 2    East Asia & Pacific  1974
# 3    East Asia & Pacific  1975
# 4    East Asia & Pacific  1976
# ..                   ...   ...
# 212   Sub-Saharan Africa  1998
# 213   Sub-Saharan Africa  1999
# 214   Sub-Saharan Africa  2000
# 215   Sub-Saharan Africa  2001
# 216   Sub-Saharan Africa  2002
#
#      Adjusted savings: mineral depletion (current US$)  \
# 0                                         2.376767e+07
# 1                                         4.719215e+07
# 2                                         7.493609e+07
# 3                                         5.113908e+07
# 4                                         6.617770e+07
# ..                                                 ...
# 212                                       1.338435e+07
# 213                                       1.043625e+07
# 214                                       1.611706e+07
# 215                                       1.440958e+07
# 216                                       2.490374e+07
#
#      Adjusted savings: energy depletion (current US$)  Population (Total)  \
# 0                                        2.857678e+07        3.718566e+07
# 1                                        5.543890e+07        3.801573e+07
# 2                                        2.545059e+08        3.884021e+07
# 3                                        3.281484e+08        3.958458e+07
# 4                                        3.971758e+08        4.024638e+07
# ..                                                ...                 ...
# 212                                      1.768939e+08        1.312151e+07
# 213                                      2.499881e+08        1.347487e+07
# 214                                      4.897455e+08        1.383849e+07
# 215                                      4.235934e+08        1.420831e+07
# 216                                      3.896983e+08        1.458791e+07
#
#      Population growth (annual %)  \
# 0                        2.397581
# 1                        2.295845
# 2                        2.178689
# 3                        1.972965
# 4                        1.665427
# ..                            ...
# 212                      2.755472
# 213                      2.728549
# 214                      2.629505
# 215                      2.533223
# 216                      2.537434
#
#      Population density (people per sq. km of land area)  \
# 0                                           533.174422
# 1                                           537.804051
# 2                                           540.798573
# 3                                           544.445167
# 4                                           546.012883
# ..                                                 ...
# 212                                          70.368442
# 213                                          72.338556
# 214                                          74.179098
# 215                                          75.917126
# 216                                          77.686792
#
#      Rural population (% of total population)  Urban population (% of total)  \
# 0                                   56.599411                      43.400589
# 1                                   56.085422                      43.914578
# 2                                   55.571433                      44.428567
# 3                                   55.057444                      44.942556
# 4                                   54.671939                      45.328061
# ..                                        ...                            ...
# 212                                 66.523587                      33.476413
# 213                                 66.143096                      33.856904
# 214                                 65.762604                      34.237396
# 215                                 65.363400                      34.636600
# 216                                 64.964196                      35.035804
#
#      Rural population  Urban population  Urban population growth (annual %)  \
# 0        2.784846e+07      9.337198e+06                            3.425587
# 1        2.842408e+07      9.591654e+06                            3.163113
# 2        2.897133e+07      9.868888e+06                            2.816442
# 3        2.945685e+07      1.012773e+07                            2.224506
# 4        2.980208e+07      1.044430e+07                            3.312721
# ..                ...               ...                                 ...
# 212      9.019798e+06      4.101712e+06                            4.075606
# 213      9.213063e+06      4.261806e+06                            4.009420
# 214      9.410219e+06      4.428269e+06                            3.875116
# 215      9.606087e+06      4.602225e+06                            3.807134
# 216      9.805642e+06      4.782263e+06                            3.784896
#
#      Urban population 5 years in the future
# 0                              1.076396e+07
# 1                              1.108756e+07
# 2                              1.142073e+07
# 3                              1.175420e+07
# 4                              1.219939e+07
# ..                                      ...
# 212                            4.965176e+06
# 213                            5.154985e+06
# 214                            5.352041e+06
# 215                            5.560592e+06
# 216                            5.777149e+06
#
# [217 rows x 13 columns]

# %%
e_asia_pacific = df['Urban population'].loc[df['World bank region'] == 'East Asia & Pacific']
eu_cent_asia = df['Urban population'].loc[df['World bank region'] == 'Europe & Central Asia']
lat_am_carib = df['Urban population'].loc[df['World bank region'] == 'Latin America & Caribbean']
mid_east_n_africa = df['Urban population'].loc[df['World bank region'] == 'Middle East & North Africa']
n_america = df['Urban population'].loc[df['World bank region'] == 'North America']
s_asia = df['Urban population'].loc[df['World bank region'] == 'South Asia']
sub_saharan_africa = df['Urban population'].loc[df['World bank region'] == 'Sub-Saharan Africa']
regions_list = [e_asia_pacific, eu_cent_asia, lat_am_carib, mid_east_n_africa, n_america, s_asia, sub_saharan_africa]

# %% [markdown]
# Our null hypothesis is that there is no distinguishable difference between observations in one region and observations in another. Our alternative hypothesis is that there is a distinguishable difference between the observations in two different groups. We will test our hypothesis with a t-test below.

# %%
# Performing a t-test
for (x, y) in combinations(regions_list, 2):
    print(ttest_ind(x, y, equal_var=False))
# Out:
# Ttest_indResult(statistic=3.758064053059629, pvalue=0.00017887791398298207)
# Ttest_indResult(statistic=4.9395102118281615, pvalue=8.769286276920863e-07)
# Ttest_indResult(statistic=6.077748888419763, pvalue=1.6314257137002197e-09)
# Ttest_indResult(statistic=-5.952090768758806, pvalue=4.137256764281877e-08)
# Ttest_indResult(statistic=-3.648437470960085, pvalue=0.0003092648167930066)
# Ttest_indResult(statistic=8.37394836601575, pvalue=1.6258113207705949e-16)
# Ttest_indResult(statistic=2.9527718003919907, pvalue=0.0031799202395374347)
# Ttest_indResult(statistic=6.633436247955836, pvalue=4.09008479939325e-11)
# Ttest_indResult(statistic=-6.725307903703273, pvalue=1.4301828119023006e-09)
# Ttest_indResult(statistic=-5.219561303031494, pvalue=3.752639510891536e-07)
# Ttest_indResult(statistic=15.316601947616295, pvalue=2.871062466917785e-50)
# Ttest_indResult(statistic=2.2680463186315456, pvalue=0.023449714845955417)
# Ttest_indResult(statistic=-6.958436907875952, pvalue=4.794797902252328e-10)
# Ttest_indResult(statistic=-5.676046011942843, pvalue=3.736771308135394e-08)
# Ttest_indResult(statistic=8.392003172954887, pvalue=1.2058535583288285e-16)
# Ttest_indResult(statistic=-7.135771297001077, pvalue=2.1398028771382485e-10)
# Ttest_indResult(statistic=-6.041471815716799, pvalue=5.516423895437269e-09)
# Ttest_indResult(statistic=9.727789453840447, pvalue=2.5042926961512054e-21)
# Ttest_indResult(statistic=3.6717549705936543, pvalue=0.00034131562053004295)
# Ttest_indResult(statistic=7.528831249835014, pvalue=3.389481086758228e-11)
# Ttest_indResult(statistic=6.8311264089166714, pvalue=6.49456570861638e-11)

# %%
# Here we see that when performing the t-test on the two regions that contain the two outliers and are also
# geographically nearby with some history of overlapping cultures, the p-value is much higher.
ttest_ind(e_asia_pacific, s_asia, equal_var=False)
# Out:
# Ttest_indResult(statistic=-3.648437470960085, pvalue=0.0003092648167930066)

# %%
ttest_ind(mid_east_n_africa, sub_saharan_africa, equal_var=False)
# Out:
# Ttest_indResult(statistic=9.727789453840447, pvalue=2.5042926961512054e-21)

# %%
_ = plt.figure(figsize=(12,8))
_ = sns.lineplot(x='year', y='Urban population', hue='World bank region', data=region_year)
_ = plt.legend(fontsize='xx-small')
_ = plt.title('Urban Population Trend by Region')
plt.show()

# %%
_ = plt.figure(figsize=(12,8))
_ = sns.lineplot(x='year', y='Population (Total)', hue='World bank region', data=region_year)
_ = plt.legend(fontsize='xx-small')
_ = plt.title('Total Population (by Region) Over the Years')
plt.show()

# %%
# If we are curious, we can see which countries are in a specific region as below
df['country'][df['World bank region'] == 'North America'].unique()
# Out:
# array(['Bermuda', 'Canada', 'United States'], dtype=object)

# %%
# Can single out a country by: 
country = df.query('country == "China"')
country.plot("year", "Urban population")
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# # Data by income

# %%
wb_income = df['World bank, 4 income groups 2017'].unique().tolist()
wb_income
# Out:
# ['Low income', 'Upper middle income', 'High income', 'Lower middle income']

# %%
# We can also see how many countries are in each income level group
countries_per_income_level = dict(df.groupby('World bank, 4 income groups 2017')['country'].nunique())
countries_per_income_level
# Out:
# {'High income': 72,
#  'Low income': 31,
#  'Lower middle income': 52,
#  'Upper middle income': 55}

# %%
# We can create a plot to visualize how many countries are in each income group
income_keys = list(countries_per_income_level.keys())
income_values = list(countries_per_income_level.values())

_ = plt.figure(figsize=(11,8))
_ = sns.barplot(income_keys, income_values, order=['High income', 'Upper middle income', 'Lower middle income', 
                                                   'Low income'])
_ = plt.xlabel('Income Group')
_ = plt.ylabel('Country Count')
_ = plt.title('Number of Countries per Income Group')
plt.tight_layout()
plt.show()

# %%
# Total Popupulation Numbers by Income
income_pop_tot_2002 = dict(df['Population (Total)'][df.year == 2002].groupby(df['World bank, 4 income groups 2017'])
                           .sum())
income_pop_tot_2002
# Out:
# {'High income': 1061860535.0,
#  'Low income': 446026847.0,
#  'Lower middle income': 2401753297.0,
#  'Upper middle income': 2323809235.0}

# %%
for key in income_pop_tot_2002: 
    print("{:.0f}%".format(income_pop_tot_2002[key]/world_pop_tot_2002*100, 2), 
          "of the world's population was in the", key, "country bracket in 2002")
# Out:
# 17% of the world's population was in the High income country bracket in 2002
# 7% of the world's population was in the Low income country bracket in 2002
# 39% of the world's population was in the Lower middle income country bracket in 2002
# 37% of the world's population was in the Upper middle income country bracket in 2002

# %%
# We can create a plot to visualize how many countries are in each income group
income_keys = list(countries_per_income_level.keys())
income_values = list(countries_per_income_level.values())

_ = plt.figure(figsize=(11,8))
_ = sns.barplot(list(income_pop_tot_2002.keys()), list(income_pop_tot_2002.values()), 
                order=['High income', 'Upper middle income', 'Lower middle income', 'Low income'])
_ = plt.xlabel('Income Group')
_ = plt.ylabel('Population')
_ = plt.title('Population per Income Group')
plt.tight_layout()
plt.savefig('Population per Income Group.png')
plt.show()

# %%
_ = plt.figure(figsize=(10,8))
_ = sns.distplot(urban_pop_perc_2002['Urban population']
                 .loc[urban_pop_perc_2002['World bank, 4 income groups 2017'] == 'High income'], bins=50,
                 label='High income')
_ = sns.distplot(urban_pop_perc_2002['Urban population']
                 .loc[urban_pop_perc_2002['World bank, 4 income groups 2017'] == 'Low income'], bins=50, 
                 label='Low income')
_ = sns.distplot(urban_pop_perc_2002['Urban population']
                 .loc[urban_pop_perc_2002['World bank, 4 income groups 2017'] == 'Lower middle income'], bins=50, 
                 label ='Lower middle income')
_ = sns.distplot(urban_pop_perc_2002['Urban population']
                 .loc[urban_pop_perc_2002['World bank, 4 income groups 2017'] == 'Upper middle income'], bins=50, 
                 label ='Upper middle income')
_ = plt.title('Population Distribution by Income Group')
plt.legend()
plt.show()

# %%
_ = plt.figure(figsize=(10,8))
_ = sns.distplot(urban_pop_perc_2002['Urban population']
                 .loc[(urban_pop_perc_2002['World bank, 4 income groups 2017'] == 'High income')
                     & (urban_pop_perc_2002['Urban population'] < 1e8)], bins=50,
                 label='High income')
_ = sns.distplot(urban_pop_perc_2002['Urban population']
                 .loc[(urban_pop_perc_2002['World bank, 4 income groups 2017'] == 'Low income')
                     & (urban_pop_perc_2002['Urban population'] < 1e8)], bins=50, 
                 label='Low income')
_ = sns.distplot(urban_pop_perc_2002['Urban population']
                 .loc[(urban_pop_perc_2002['World bank, 4 income groups 2017'] == 'Lower middle income')
                     & (urban_pop_perc_2002['Urban population'] < 1e8)], bins=50, 
                 label ='Lower middle income')
_ = sns.distplot(urban_pop_perc_2002['Urban population']
                 .loc[(urban_pop_perc_2002['World bank, 4 income groups 2017'] == 'Upper middle income')
                     & (urban_pop_perc_2002['Urban population'] < 1e8)], bins=50, 
                 label ='Upper middle income')
_ = plt.title('Population Distribution by Income Group (Excluding Outliers > 2.5e8)')
plt.legend()
plt.show()

# %%
_ = plt.figure(figsize=(10,8))
_ = sns.distplot(urban_pop_perc_2002['Urban population']
                 .loc[urban_pop_perc_2002['World bank, 4 income groups 2017'] == 'High income'], bins=20,
                 label='High income')
_ = plt.title('High Income Urban Population Distribution')
plt.show()

# %%
_ = plt.figure(figsize=(10,8))
_ = sns.distplot(urban_pop_perc_2002['Urban population']
                 .loc[urban_pop_perc_2002['World bank, 4 income groups 2017'] == 'Upper middle income'], bins=20,
                 label='High income', color='red')
_ = plt.title('Upper Middle Income Urban Population Distribution')
plt.show()

# %%
_ = plt.figure(figsize=(10,8))
_ = sns.distplot(urban_pop_perc_2002['Urban population']
                 .loc[urban_pop_perc_2002['World bank, 4 income groups 2017'] == 'Lower middle income'], bins=20,
                 label='High income', color='green')
_ = plt.title('Lower Middle Income Urban Population Distribution')
plt.show()

# %%
_ = plt.figure(figsize=(10,8))
_ = sns.distplot(urban_pop_perc_2002['Urban population']
                 .loc[urban_pop_perc_2002['World bank, 4 income groups 2017'] == 'Low income'], bins=20,
                 label='High income', color='orange')
_ = plt.title('Low Income Urban Population Distribution')
plt.show()

# %%
income_year = df.groupby(['World bank, 4 income groups 2017', 'year'], as_index=False).mean()
income_year
# Out:
#     World bank, 4 income groups 2017  year  \
# 0                        High income  1972
# 1                        High income  1973
# 2                        High income  1974
# 3                        High income  1975
# 4                        High income  1976
# ..                               ...   ...
# 119              Upper middle income  1998
# 120              Upper middle income  1999
# 121              Upper middle income  2000
# 122              Upper middle income  2001
# 123              Upper middle income  2002
#
#      Adjusted savings: mineral depletion (current US$)  \
# 0                                         3.465747e+07
# 1                                         7.494475e+07
# 2                                         1.135059e+08
# 3                                         6.776935e+07
# 4                                         6.966476e+07
# ..                                                 ...
# 119                                       1.242590e+08
# 120                                       1.072247e+08
# 121                                       1.519813e+08
# 122                                       1.314196e+08
# 123                                       1.520822e+08
#
#      Adjusted savings: energy depletion (current US$)  Population (Total)  \
# 0                                        2.162264e+08        1.178996e+07
# 1                                        3.400483e+08        1.189617e+07
# 2                                        1.194020e+09        1.201717e+07
# 3                                        1.131033e+09        1.213268e+07
# 4                                        1.316821e+09        1.222767e+07
# ..                                                ...                 ...
# 119                                      1.676085e+09        4.072353e+07
# 120                                      2.133326e+09        4.114133e+07
# 121                                      4.373771e+09        4.153448e+07
# 122                                      3.901273e+09        4.190122e+07
# 123                                      3.558464e+09        4.225108e+07
#
#      Population growth (annual %)  \
# 0                        1.973140
# 1                        2.011452
# 2                        1.924697
# 3                        1.822524
# 4                        1.636394
# ..                            ...
# 119                      1.136058
# 120                      1.190763
# 121                      1.084174
# 122                      1.042151
# 123                      0.998422
#
#      Population density (people per sq. km of land area)  \
# 0                                           532.963769
# 1                                           538.876237
# 2                                           543.962370
# 3                                           549.241657
# 4                                           553.244221
# ..                                                 ...
# 119                                         109.882992
# 120                                         111.072435
# 121                                         112.191031
# 122                                         113.357581
# 123                                         114.558123
#
#      Rural population (% of total population)  Urban population (% of total)  \
# 0                                   34.797439                      65.202561
# 1                                   34.236047                      65.763953
# 2                                   33.674656                      66.325344
# 3                                   33.113264                      66.886736
# 4                                   32.653650                      67.346350
# ..                                        ...                            ...
# 119                                 43.748924                      56.251076
# 120                                 43.382662                      56.617338
# 121                                 43.016400                      56.983600
# 122                                 42.671822                      57.328178
# 123                                 42.327244                      57.672756
#
#      Rural population  Urban population  Urban population growth (annual %)  \
# 0        3.574704e+06      8.215256e+06                            2.943833
# 1        3.564394e+06      8.331772e+06                            2.956654
# 2        3.557202e+06      8.459969e+06                            2.845245
# 3        3.548750e+06      8.583925e+06                            2.720147
# 4        3.547791e+06      8.679878e+06                            2.379026
# ..                ...               ...                                 ...
# 119      2.080547e+07      1.991807e+07                            1.801406
# 120      2.071053e+07      2.043080e+07                            1.846003
# 121      2.059618e+07      2.093831e+07                            1.730452
# 122      2.039762e+07      2.150360e+07                            1.659378
# 123      2.018357e+07      2.206750e+07                            1.601057
#
#      Urban population 5 years in the future
# 0                              8.780447e+06
# 1                              8.883716e+06
# 2                              8.990461e+06
# 3                              9.095011e+06
# 4                              9.196645e+06
# ..                                      ...
# 119                            2.262876e+07
# 120                            2.319000e+07
# 121                            2.375618e+07
# 122                            2.432754e+07
# 123                            2.489827e+07
#
# [124 rows x 13 columns]

# %%
low_income = df['Urban population'].loc[df['World bank, 4 income groups 2017'] == 'Low income']
lower_mid_income = df['Urban population'].loc[df['World bank, 4 income groups 2017'] == 'Lower middle income']
upper_mid_income = df['Urban population'].loc[df['World bank, 4 income groups 2017'] == 'Upper middle income']
high_income = df['Urban population'].loc[df['World bank, 4 income groups 2017'] == 'High income']
income_groups = [low_income, lower_mid_income, upper_mid_income, high_income]

# %%
# Performing a t-test
for (x, y) in combinations(income_groups, 2):
    print(ttest_ind(x, y, equal_var=False))
# Out:
# Ttest_indResult(statistic=-10.673565271695102, pvalue=9.34962205414416e-26)
# Ttest_indResult(statistic=-11.753065713728338, pvalue=1.0041564237655659e-30)
# Ttest_indResult(statistic=-13.69113161656419, pvalue=4.243699114187797e-41)
# Ttest_indResult(statistic=-3.426956743643441, pvalue=0.0006186026555457015)
# Ttest_indResult(statistic=0.6364782202033037, pvalue=0.5245121265743573)
# Ttest_indResult(statistic=4.2357643954965765, pvalue=2.3588456799174375e-05)

# %%
ttest_ind(lower_mid_income, high_income, equal_var=False)
# Out:
# Ttest_indResult(statistic=0.6364782202033037, pvalue=0.5245121265743573)

# %%
_ = plt.figure(figsize=(12,8))
_ = sns.lineplot(x='year', y='Urban population', hue='World bank, 4 income groups 2017', data=income_year)
_ = plt.legend(fontsize='x-small')
_ = plt.title('Urban Population Trend by Income Group')
plt.show()

# %%
_ = plt.figure(figsize=(12,8))
_ = sns.lineplot(x='year', y='Population (Total)', hue='World bank, 4 income groups 2017', data=income_year)
_ = plt.legend(fontsize='x-small')
_ = plt.title('Total Population (by Income Group) Over the Years')
plt.show()

# %% [markdown]
# ### Lineplots

# %%
_ = sns.lmplot(x='Population (Total)', y='Urban population', data=df[df.year == 2002])
plt.show()

# %%
_ = sns.residplot(x='Population (Total)', y='Urban population', data=df[df.year == 2002], color='green')
plt.show()

# %%
# Excluding the outliers > 1e9 (China and India)
_ = sns.lmplot(x='Population (Total)', y='Urban population', 
               data=df[(df.year == 2002) & (df['Population (Total)'] < 1e9)])
plt.show()

# %%
_ = sns.residplot(x='Population (Total)', y='Urban population', 
              data=df[(df.year == 2002) & (df['Population (Total)'] < 1e9)], color='green')
plt.show()

# %%
_ = sns.lmplot(x='Population (Total)', y='Urban population', data=df[(df['World bank region'] == "South Asia") 
          & (df.year == 2002) & (df['Population (Total)'] < 1e9)])
plt.show()

# %% [markdown]
# ## Visualizing Trends in Various Countries

# %% [markdown]
# ### Most Populous Countries (as of 2002)

# %%
cols = df.columns

# %%
# China

for series_name in cols[4:-1]:
    _ = plt.plot(df[df['country'] == 'China']['year'], 
             df[df['country'] == 'China'][series_name])
    _ = plt.xlabel('Year')
    _ = plt.ylabel('Value')
    _ = plt.title(series_name)
    plt.show()

# %%
# India

for series_name in cols[4:-1]:
    _ = plt.plot(df[df['country'] == 'India']['year'], 
             df[df['country'] == 'India'][series_name])
    _ = plt.xlabel('Year')
    _ = plt.ylabel('Value')
    _ = plt.title(series_name)
    plt.show()

# %%
# United States

for series_name in cols[4:-1]:
    _ = plt.plot(df[df['country'] == 'United States']['year'], 
             df[df['country'] == 'United States'][series_name])
    _ = plt.xlabel('Year')
    _ = plt.ylabel('Value')
    _ = plt.title(series_name)
    plt.show()

# %% [markdown]
# ### Least Populous Countries (as of 2002)

# %%
# Turks and Caicos Islands

for series_name in cols[4:-1]:
    _ = plt.plot(df[df['country'] == 'Turks and Caicos Islands']['year'], 
             df[df['country'] == 'Turks and Caicos Islands'][series_name])
    _ = plt.xlabel('Year')
    _ = plt.ylabel('Value')
    _ = plt.title(series_name)
    plt.show()

# %%
# Palau

for series_name in cols[4:-1]:
    _ = plt.plot(df[df['country'] == 'Palau']['year'], 
             df[df['country'] == 'Palau'][series_name])
    _ = plt.xlabel('Year')
    _ = plt.ylabel('Value')
    _ = plt.title(series_name)
    plt.show()

# %%
# Tuvalu

for series_name in cols[4:-1]:
    _ = plt.plot(df[df['country'] == 'Tuvalu']['year'], 
             df[df['country'] == 'Tuvalu'][series_name])
    _ = plt.xlabel('Year')
    _ = plt.ylabel('Value')
    _ = plt.title(series_name)
    plt.show()
